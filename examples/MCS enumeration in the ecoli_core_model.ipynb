# %% [markdown]
# # MCS enumeration in the ecoli_core_model
#
# This notebook provides an example on how to use *metaconvexpy* to calculate minimal cut sets coupled with the model reading and flux analysis capabilities of the *COBRApy* package.

# %% [markdown]
# ## Model reading and setup

# %% [markdown]
# Download the SBML model from the BiGG models repository

# %%
import urllib

model_url = "http://bigg.ucsd.edu/static/models/e_coli_core.xml"
model_path, model_content = urllib.request.urlretrieve(model_url)

# %% [markdown]
# Read the SBML temporary file generated from the HTTP request content and generate a COBRA Model object from it. Two functions are defined to assist in further analyses:
# * *revert_bounds* - restores all model bounds to their original values
# * *apply_kos(**kos**)* - knocks out reactions contained in *kos* (any iterable containing reaction IDs)

# %%
import cobra

model = cobra.io.sbml3.read_sbml_model(model_path)
model_bounds = {r.id:(r.lower_bound, r.upper_bound) for r in model.reactions}

def revert_bounds():
    for r in model.reactions:
        r.lower_bound, r.upper_bound = model_bounds[r.id]

def apply_kos(kos):
    for ko in kos:
        model.reactions.get_by_id(ko).knock_out()
        
model
# Out:
# <Model e_coli_core at 0x7f8a5243d0f0>

# %% [markdown]
# Extracting environmental conditions from the model, assuming the maximum capacity constant of 1000.
# This will be needed some steps further for the MCSEnumerator approach.

# %%
{r.id:(r.lower_bound, r.upper_bound) 
 for r in model.reactions 
 if (r.lower_bound not in [-1000, 0]) or (r.upper_bound not in [0, 1000])}
# Out:
# {'ATPM': (8.39, 1000.0), 'EX_glc__D_e': (-10.0, 1000.0)}

# %% [markdown]
# ## Import *metaconvexpy* and enumerate minimal cut sets

# %% [markdown]
# Import the MCSEnumerator wrapper class (KShortestMCSEnumeratorWrapper) that works with COBRA models.

# %%
from src.metaconvexpy.utilities.external_wrappers import KShortestEFMEnumeratorWrapper, KShortestMCSEnumeratorWrapper

# %% [markdown]
# Define the region of the flux space that the MCSs are supposed to block. In this scenario, we are attempting to improve succinate production using glucose as a carbon source. The following IDs are required:
# * Succinate exchange : 'EX_succ_e'
# * Glucose exchange: 'EX_glc__D_e'
# * Maintenance ATP: 'ATPM'

# %%
yield_space = {
    ('EX_succ_e','EX_glc__D_e'):(-0.001, None, 0),
}

flux_space = {
    'EX_glc__D_e': (-10, None),
    'ATPM' : (8.39, None)
}

# %% [markdown]
# Having defined the flux space, we can now start the algorithm. The wrapper for MCSEnumerator requires the following parameters:
# * *model*: A model instance from COBRA, framed or any other framework if a ModelReader subclass is implemented for it and added to the list of readers
# * *target_flux_space_dict*: A dictionary (str -> tuple(float, float)) mapping reaction identifiers to flux bounds representing the target flux space for minimal cut sets.
# * *target_yield_space_dict*: A dictionary ((str, str) -> tuple(float, float, float)) mapping product/substrate pairs to a lower and upper bound for the yield constraint between both fluxes and a deviation value for the constraint.
# * *algorithm_type*: Can be one of two values:
#     * Enumerate one size at a time: *KShortestMCSEnumeratorWrapper.ALGORITHM_TYPE_POPULATE*
#     * Enumerate one solution at a time: *KShortestMCSEnumeratorWrapper.ALGORITHM_TYPE_ITERATIVE*
# * *stop_criteria*: An integer defining the maximum number of iterations. If the POPULATE routine is used, the algorithm will yield all solutions that have size <stop_criteria> and below. On the other hand, if ITERATIVE is used, the algorithm will yield the <stop_criteria>-shortest solutions.

# %%
ksefm = KShortestMCSEnumeratorWrapper(
    model, 
    target_flux_space_dict=flux_space, 
    target_yield_space_dict=yield_space, 
    algorithm_type=KShortestMCSEnumeratorWrapper.ALGORITHM_TYPE_POPULATE, 
    stop_criteria=5)

# %% [markdown]
# The MILP problems aren't actually run once the KShortestMCSEnumeratorWrapper instance is created. To obtain the solutions, the .get_enumerator() method must be called. This method returns a generator that can be called in several ways.

# %%
enumerator = ksefm.get_enumerator()

# %% [markdown]
# Depending on time constraints, one can interactively call the *next* function on the enumerator so it iterates just once. This is useful when the problem is large or when exploring new constraints.

# %%
solutions = next(enumerator)
# Out:
# Starting size 1

# %% [markdown]
# Solutions are always lists of dictionaries mapping fluxes with values for all active fluxes. For MCSs, one simply has to obtain the dictionary keys for all elements of the list

# %%
mcs = [set(d.keys()) for d in solutions]
mcs
# Out:
# [{'ATPM'},
#  {'GLCpts'},
#  {'EX_glc__D_e'},
#  {'GAPD'},
#  {'PGK'},
#  {'ENO'},
#  {'PGM'},
#  {'EX_h2o_e'},
#  {'GLUSy', 'H2Ot'},
#  {'EX_succ_e'},
#  {'SUCCt3'},
#  {'EX_h_e'},
#  {'NADH16'}]

# %% [markdown]
# Unlike the previous approach, we can try and extensively enumerate all MCSs. We must redefine the enumerator as it already iterated once. We can import the *chain* function and use it to get a list of solutions until the stop criteria is reached.

# %%
enumerator = ksefm.get_enumerator()

# %%
from itertools import chain
solutions = list(chain(*ksefm.get_enumerator()))
# Out:
# Starting size 1
# Starting size 2
# Starting size 3
# Starting size 4
# Starting size 5

# %%
mcs = [set(e.keys()) for e in solutions]
mcs
# Out:
# [{'ATPM'},
#  {'GLCpts'},
#  {'EX_glc__D_e'},
#  {'GAPD'},
#  {'PGK'},
#  {'ENO'},
#  {'PGM'},
#  {'EX_h2o_e'},
#  {'GLUSy', 'H2Ot'},
#  {'EX_succ_e'},
#  {'SUCCt3'},
#  {'EX_h_e'},
#  {'NADH16'},
#  {'EX_co2_e', 'PFK'},
#  {'EX_co2_e', 'TPI'},
#  {'CYTBD', 'TPI'},
#  {'EX_o2_e', 'TPI'},
#  {'O2t', 'TPI'},
#  {'EX_o2_e', 'FBA'},
#  {'EX_co2_e', 'FBA'},
#  {'FBA', 'O2t'},
#  {'CO2t', 'FBA'},
#  {'CYTBD', 'FBA'},
#  {'FBA', 'NADTRHD'},
#  {'RPE', 'TPI'},
#  {'RPI', 'TPI'},
#  {'TALA', 'TPI'},
#  {'TKT1', 'TPI'},
#  {'PGL', 'TPI'},
#  {'G6PDH2r', 'TPI'},
#  {'GND', 'TPI'},
#  {'NADTRHD', 'TPI'},
#  {'GND', 'PFK'},
#  {'PFK', 'TKT2'},
#  {'PFK', 'RPE'},
#  {'TKT2', 'TPI'},
#  {'PGI', 'TPI'},
#  {'G6PDH2r', 'PFK'},
#  {'EX_o2_e', 'PFK'},
#  {'PFK', 'TALA'},
#  {'O2t', 'PFK'},
#  {'PFK', 'RPI'},
#  {'PFK', 'TKT1'},
#  {'CYTBD', 'PFK'},
#  {'PFK', 'PGI'},
#  {'CO2t', 'PFK'},
#  {'NADTRHD', 'PFK'},
#  {'PFK', 'PGL'},
#  {'FBA', 'PGI'},
#  {'FBA', 'PGL'},
#  {'FBA', 'TKT1'},
#  {'FBA', 'GND'},
#  {'FBA', 'RPE'},
#  {'FBA', 'RPI'},
#  {'FBA', 'TALA'},
#  {'FBA', 'TKT2'},
#  {'FBA', 'G6PDH2r'},
#  {'ACONTa', 'FUM'},
#  {'EX_o2_e', 'FUM'},
#  {'EX_o2_e', 'FRD7'},
#  {'EX_co2_e', 'FUM'},
#  {'EX_co2_e', 'FRD7'},
#  {'ACONTa', 'MDH'},
#  {'ACONTb', 'FRD7'},
#  {'ACONTb', 'FUM'},
#  {'ACONTa', 'FRD7', 'GLUDy'},
#  {'PGI', 'TKT1'},
#  {'PGI', 'TALA'},
#  {'EX_o2_e', 'PGI'},
#  {'NADTRHD', 'PGI'},
#  {'PGI', 'PGL'},
#  {'PGI', 'TKT2'},
#  {'CYTBD', 'PGI'},
#  {'PGI', 'RPE'},
#  {'CO2t', 'FUM'},
#  {'CO2t', 'FRD7'},
#  {'CO2t', 'MDH'},
#  {'CO2t', 'PPC'},
#  {'FUM', 'O2t'},
#  {'FRD7', 'O2t'},
#  {'CYTBD', 'FRD7'},
#  {'CYTBD', 'FUM'},
#  {'CYTBD', 'PPC'},
#  {'CYTBD', 'MDH'},
#  {'EX_o2_e', 'MDH'},
#  {'MDH', 'O2t'},
#  {'ICL', 'PPC'},
#  {'MDH', 'PPC'},
#  {'CS', 'PPC'},
#  {'ACONTb', 'PPC'},
#  {'MALS', 'PPC'},
#  {'PDH', 'PPC'},
#  {'EX_o2_e', 'PPC'},
#  {'O2t', 'PPC'},
#  {'ACONTa', 'PPC'},
#  {'EX_co2_e', 'PPC'},
#  {'FUM', 'PDH'},
#  {'FRD7', 'PDH'},
#  {'GND', 'PGI'},
#  {'PGI', 'RPI'},
#  {'G6PDH2r', 'PGI'},
#  {'O2t', 'PGI'},
#  {'ACONTb', 'MDH'},
#  {'MDH', 'PDH'},
#  {'EX_co2_e', 'MDH'},
#  {'CS', 'FRD7', 'GLUDy'},
#  {'CS', 'FUM'},
#  {'CS', 'MDH'},
#  {'CO2t', 'TPI'},
#  {'EX_pyr_e', 'NADTRHD', 'PDH'},
#  {'MALS', 'PFK', 'PPS'},
#  {'ADK1', 'MALS', 'PFK'},
#  {'ICL', 'PFK', 'PPS'},
#  {'ADK1', 'PDH', 'TPI'},
#  {'ADK1', 'PDH', 'PFK'},
#  {'ACONTb', 'ADK1', 'PFK'},
#  {'ACONTb', 'PFK', 'PPS'},
#  {'ADK1', 'MDH', 'PFK'},
#  {'MDH', 'PFK', 'PPS'},
#  {'ADK1', 'CS', 'PFK'},
#  {'CS', 'PFK', 'PPS'},
#  {'PDH', 'PPS', 'TPI'},
#  {'ADK1', 'ICL', 'TPI'},
#  {'ADK1', 'MALS', 'TPI'},
#  {'PDH', 'PFK', 'PPS'},
#  {'ADK1', 'CS', 'TPI'},
#  {'CS', 'PPS', 'TPI'},
#  {'FBA', 'ICL', 'PPS'},
#  {'ADK1', 'FBA', 'ICL'},
#  {'MALS', 'PPS', 'TPI'},
#  {'ACONTb', 'ADK1', 'TPI'},
#  {'ACONTa', 'ADK1', 'PFK'},
#  {'ACONTa', 'PFK', 'PPS'},
#  {'ICL', 'PPS', 'TPI'},
#  {'ADK1', 'FBA', 'MDH'},
#  {'FBA', 'MDH', 'PPS'},
#  {'CS', 'FBA', 'PPS'},
#  {'ADK1', 'CS', 'FBA'},
#  {'PPC', 'PYK', 'TALA'},
#  {'NADTRHD', 'PPC', 'PYK'},
#  {'PPC', 'PYK', 'RPE'},
#  {'PGL', 'PPC', 'PYK'},
#  {'PGI', 'PPC', 'PYK'},
#  {'PPC', 'PYK', 'RPI'},
#  {'PPC', 'PYK', 'TKT2'},
#  {'G6PDH2r', 'PPC', 'PYK'},
#  {'PPC', 'PYK', 'TKT1'},
#  {'GND', 'PPC', 'PYK'},
#  {'ACONTb', 'FBA', 'PPS'},
#  {'ACONTb', 'ADK1', 'FBA'},
#  {'ACONTa', 'ADK1', 'TPI'},
#  {'ACONTb', 'PPS', 'TPI'},
#  {'ACONTa', 'PPS', 'TPI'},
#  {'FBA', 'MALS', 'PPS'},
#  {'ADK1', 'FBA', 'MALS'},
#  {'ACONTa', 'FBA', 'PPS'},
#  {'ACONTa', 'ADK1', 'FBA'},
#  {'ADK1', 'MDH', 'TPI'},
#  {'FBA', 'PDH', 'PPS'},
#  {'ADK1', 'FBA', 'PDH'},
#  {'MDH', 'PPS', 'TPI'},
#  {'ACALD', 'CO2t', 'EX_o2_e'},
#  {'AKGDH', 'FUM', 'ICL'},
#  {'ACALD', 'CO2t', 'CYTBD'},
#  {'ACALD', 'EX_co2_e', 'EX_o2_e'},
#  {'ICDHyr', 'ICL', 'MDH'},
#  {'AKGDH', 'FUM', 'MALS'},
#  {'ICL', 'MDH', 'SUCOAS'},
#  {'MALS', 'MDH', 'SUCOAS'},
#  {'PDH', 'PYRt2', 'TKT2'},
#  {'PDH', 'PYRt2', 'RPI'},
#  {'CO2t', 'PGI', 'PPS'},
#  {'ATPS4r', 'CO2t', 'PGI'},
#  {'ADK1', 'CO2t', 'PGI'},
#  {'EX_co2_e', 'PGI', 'PPS'},
#  {'ADK1', 'EX_co2_e', 'PGI'},
#  {'EX_pyr_e', 'PDH', 'TKT2'},
#  {'CO2t', 'EX_o2_e', 'PDH'},
#  {'FUM', 'ICL', 'SUCOAS'},
#  {'FUM', 'ICDHyr', 'ICL'},
#  {'AKGDH', 'FRD7', 'ICL'},
#  {'AKGDH', 'FRD7', 'MALS'},
#  {'PDH', 'PYRt2', 'TALA'},
#  {'EX_pyr_e', 'PDH', 'TALA'},
#  {'CO2t', 'GND', 'PDH'},
#  {'ICDHyr', 'MALS', 'MDH'},
#  {'CO2t', 'G6PDH2r', 'PDH'},
#  {'CO2t', 'PDH', 'TKT1'},
#  {'CO2t', 'PDH', 'TALA'},
#  {'CO2t', 'CYTBD', 'PDH'},
#  {'CO2t', 'PDH', 'RPI'},
#  {'CO2t', 'PDH', 'PGL'},
#  {'FRD7', 'ICDHyr', 'MALS'},
#  {'FRD7', 'MALS', 'SUCOAS'},
#  {'NADTRHD', 'PDH', 'PYRt2'},
#  {'PDH', 'PYRt2', 'TKT1'},
#  {'CO2t', 'PDH', 'RPE'},
#  {'CO2t', 'O2t', 'PDH'},
#  {'EX_co2_e', 'PDH', 'TKT1'},
#  {'CYTBD', 'EX_co2_e', 'PDH'},
#  {'EX_co2_e', 'PDH', 'PGL'},
#  {'EX_co2_e', 'PDH', 'RPE'},
#  {'EX_co2_e', 'PDH', 'TALA'},
#  {'EX_co2_e', 'PDH', 'RPI'},
#  {'EX_co2_e', 'PDH', 'TKT2'},
#  {'EX_co2_e', 'EX_o2_e', 'PDH'},
#  {'EX_pyr_e', 'PDH', 'RPI'},
#  {'ACALD', 'EX_co2_e', 'O2t'},
#  {'EX_pyr_e', 'PDH', 'PGL'},
#  {'PDH', 'PGL', 'PYRt2'},
#  {'AKGDH', 'ICL', 'MDH'},
#  {'AKGDH', 'MALS', 'MDH'},
#  {'ACALD', 'CO2t', 'O2t'},
#  {'FUM', 'MALS', 'SUCOAS'},
#  {'FUM', 'ICDHyr', 'MALS'},
#  {'EX_co2_e', 'O2t', 'PDH'},
#  {'CO2t', 'NADTRHD', 'PDH'},
#  {'G6PDH2r', 'PDH', 'PYRt2'},
#  {'EX_pyr_e', 'G6PDH2r', 'PDH'},
#  {'EX_pyr_e', 'PDH', 'TKT1'},
#  {'EX_co2_e', 'G6PDH2r', 'PDH'},
#  {'PDH', 'PYRt2', 'RPE'},
#  {'EX_pyr_e', 'PDH', 'RPE'},
#  {'ATPS4r', 'EX_co2_e', 'PGI'},
#  {'CO2t', 'PDH', 'TKT2'},
#  {'EX_co2_e', 'GND', 'PDH'},
#  {'EX_co2_e', 'NADTRHD', 'PDH'},
#  {'ACALD', 'CYTBD', 'EX_co2_e'},
#  {'GND', 'PDH', 'PYRt2'},
#  {'EX_pyr_e', 'GND', 'PDH'},
#  {'FRD7', 'ICDHyr', 'ICL'},
#  {'FRD7', 'ICL', 'SUCOAS'},
#  {'ADK1', 'ICL', 'PFK'},
#  {'ATPS4r', 'NADTRHD', 'PPC', 'SUCCt2_2'},
#  {'GLNS', 'MALS', 'MDH', 'NADTRHD'},
#  {'GLUN', 'MALS', 'MDH', 'NADTRHD', 'NH4t'},
#  {'MALS', 'MDH', 'NADTRHD', 'RPI'},
#  {'ETOHt2r', 'EX_acald_e', 'EX_co2_e', 'O2t'},
#  {'MALS', 'MDH', 'NADTRHD', 'PIt2r'},
#  {'EX_pi_e', 'FRD7', 'ICL', 'NADTRHD'},
#  {'BIOMASS_Ecoli_core_w_GAM', 'FRD7', 'ICL', 'NADTRHD'},
#  {'BIOMASS_Ecoli_core_w_GAM', 'FRD7', 'MALS', 'NADTRHD'},
#  {'FRD7', 'ICL', 'NADTRHD', 'PIt2r'},
#  {'ACALDt', 'EX_co2_e', 'EX_etoh_e', 'O2t'},
#  {'ACALDt', 'CYTBD', 'EX_co2_e', 'EX_etoh_e'},
#  {'CYTBD', 'EX_acald_e', 'EX_co2_e', 'EX_etoh_e'},
#  {'ATPS4r', 'MDH', 'SUCCt2_2', 'THD2'},
#  {'FRD7', 'ICL', 'NADTRHD', 'NH4t'},
#  {'GLNS', 'ICL', 'MDH', 'NADTRHD'},
#  {'BIOMASS_Ecoli_core_w_GAM', 'ICL', 'MDH', 'NADTRHD'},
#  {'ICL', 'MDH', 'NADTRHD', 'NH4t'},
#  {'EX_pi_e', 'ICL', 'MDH', 'NADTRHD'},
#  {'ICL', 'MDH', 'NADTRHD', 'PIt2r'},
#  {'ICL', 'MDH', 'NADTRHD', 'RPI'},
#  {'EX_nh4_e', 'ICL', 'MDH', 'NADTRHD'},
#  {'ACALDt', 'ALCD2x', 'CYTBD', 'EX_co2_e'},
#  {'ACALDt', 'CYTBD', 'ETOHt2r', 'EX_co2_e'},
#  {'CYTBD', 'ETOHt2r', 'EX_acald_e', 'EX_co2_e'},
#  {'ATPS4r', 'PGI', 'SUCCt2_2', 'THD2'},
#  {'ATPS4r', 'PFK', 'SUCCt2_2', 'THD2'},
#  {'ALCD2x', 'CYTBD', 'EX_acald_e', 'EX_co2_e'},
#  {'FRD7', 'GLNS', 'ICL', 'NADTRHD'},
#  {'EX_pi_e', 'MALS', 'MDH', 'NADTRHD'},
#  {'EX_acald_e', 'EX_co2_e', 'EX_etoh_e', 'O2t'},
#  {'FUM', 'GLNS', 'MALS', 'NADTRHD'},
#  {'EX_pi_e', 'FUM', 'MALS', 'NADTRHD'},
#  {'FUM', 'MALS', 'NADTRHD', 'RPI'},
#  {'FUM', 'GLNS', 'ICL', 'NADTRHD'},
#  {'FUM', 'ICL', 'NADTRHD', 'RPI'},
#  {'EX_pi_e', 'FUM', 'ICL', 'NADTRHD'},
#  {'FUM', 'ICL', 'NADTRHD', 'NH4t'},
#  {'EX_nh4_e', 'FUM', 'MALS', 'NADTRHD'},
#  {'EX_nh4_e', 'FRD7', 'ICL', 'NADTRHD'},
#  {'ATPS4r', 'SUCCt2_2', 'THD2', 'TPI'},
#  {'ACALDt', 'ALCD2x', 'CO2t', 'CYTBD'},
#  {'ADK1', 'D_LACt2', 'EX_pyr_e', 'PDH'},
#  {'D_LACt2', 'EX_pyr_e', 'PDH', 'PPS'},
#  {'EX_pyr_e', 'LDH_D', 'PDH', 'PPS'},
#  {'ADK1', 'EX_pyr_e', 'LDH_D', 'PDH'},
#  {'EX_o2_e', 'EX_pyr_e', 'LDH_D', 'PDH'},
#  {'D_LACt2', 'EX_pyr_e', 'O2t', 'PDH'},
#  {'CYTBD', 'D_LACt2', 'EX_pyr_e', 'PDH'},
#  {'CYTBD', 'EX_pyr_e', 'LDH_D', 'PDH'},
#  {'D_LACt2', 'EX_pyr_e', 'PDH', 'PGI'},
#  {'EX_lac__D_e', 'EX_pyr_e', 'PDH', 'PGI'},
#  {'ACALDt', 'CO2t', 'ETOHt2r', 'O2t'},
#  {'ALCD2x', 'EX_acald_e', 'EX_co2_e', 'O2t'},
#  {'ATPS4r', 'FBA', 'SUCCt2_2', 'THD2'},
#  {'FUM', 'MALS', 'NADTRHD', 'NH4t'},
#  {'ATPS4r', 'PPC', 'SUCCt2_2', 'THD2'},
#  {'BIOMASS_Ecoli_core_w_GAM', 'FUM', 'MALS', 'NADTRHD'},
#  {'BIOMASS_Ecoli_core_w_GAM', 'FUM', 'ICL', 'NADTRHD'},
#  {'BIOMASS_Ecoli_core_w_GAM', 'MALS', 'MDH', 'NADTRHD'},
#  {'ACALDt', 'CO2t', 'CYTBD', 'ETOHt2r'},
#  {'CO2t', 'CYTBD', 'ETOHt2r', 'EX_acald_e'},
#  {'CYTBD', 'EX_lac__D_e', 'EX_pyr_e', 'PDH'},
#  {'EX_pyr_e', 'LDH_D', 'O2t', 'PDH'},
#  {'D_LACt2', 'EX_o2_e', 'EX_pyr_e', 'PDH'},
#  {'ACALDt', 'ETOHt2r', 'EX_co2_e', 'O2t'},
#  {'ACALDt', 'ALCD2x', 'CO2t', 'EX_o2_e'},
#  {'FUM', 'ICL', 'NADTRHD', 'PIt2r'},
#  {'ALCD2x', 'CO2t', 'EX_acald_e', 'EX_o2_e'},
#  {'ACALDt', 'CO2t', 'ETOHt2r', 'EX_o2_e'},
#  {'CO2t', 'ETOHt2r', 'EX_acald_e', 'EX_o2_e'},
#  {'EX_pyr_e', 'LDH_D', 'PDH', 'PGI'},
#  {'ACALDt', 'CO2t', 'EX_etoh_e', 'O2t'},
#  {'CO2t', 'EX_acald_e', 'EX_etoh_e', 'O2t'},
#  {'FRD7', 'ICL', 'NADTRHD', 'RPI'},
#  {'ACALDt', 'CO2t', 'CYTBD', 'EX_etoh_e'},
#  {'CO2t', 'CYTBD', 'EX_acald_e', 'EX_etoh_e'},
#  {'ATPS4r', 'D_LACt2', 'EX_pyr_e', 'PDH'},
#  {'EX_lac__D_e', 'EX_pyr_e', 'PDH', 'PPS'},
#  {'EX_lac__D_e', 'EX_o2_e', 'EX_pyr_e', 'PDH'},
#  {'ATPS4r', 'EX_lac__D_e', 'EX_pyr_e', 'PDH'},
#  {'EX_lac__D_e', 'EX_pyr_e', 'O2t', 'PDH'},
#  {'ADK1', 'EX_lac__D_e', 'EX_pyr_e', 'PDH'},
#  {'CO2t', 'ETOHt2r', 'EX_acald_e', 'O2t'},
#  {'EX_nh4_e', 'FUM', 'ICL', 'NADTRHD'},
#  {'FUM', 'MALS', 'NADTRHD', 'PIt2r'},
#  {'ACALDt', 'ALCD2x', 'EX_co2_e', 'O2t'},
#  {'ATPS4r', 'EX_pyr_e', 'LDH_D', 'PDH'},
#  {'ALCD2x', 'CO2t', 'CYTBD', 'EX_acald_e'},
#  {'ATPS4r', 'D_LACt2', 'PDH', 'PYRt2'},
#  {'ADK1', 'D_LACt2', 'PDH', 'PYRt2'},
#  {'D_LACt2', 'PDH', 'PPS', 'PYRt2'},
#  {'ADK1', 'EX_lac__D_e', 'PDH', 'PYRt2'},
#  {'D_LACt2', 'EX_o2_e', 'PDH', 'PYRt2'},
#  {'D_LACt2', 'O2t', 'PDH', 'PYRt2'},
#  {'EX_lac__D_e', 'PDH', 'PPS', 'PYRt2'},
#  {'EX_lac__D_e', 'EX_o2_e', 'PDH', 'PYRt2'},
#  {'ACALDt', 'ALCD2x', 'CO2t', 'O2t'},
#  {'ALCD2x', 'CO2t', 'EX_acald_e', 'O2t'},
#  {'ATPS4r', 'EX_lac__D_e', 'PDH', 'PYRt2'},
#  {'EX_lac__D_e', 'O2t', 'PDH', 'PYRt2'},
#  {'D_LACt2', 'PDH', 'PGI', 'PYRt2'},
#  {'LDH_D', 'PDH', 'PGI', 'PYRt2'},
#  {'EX_lac__D_e', 'PDH', 'PGI', 'PYRt2'},
#  {'CYTBD', 'D_LACt2', 'PDH', 'PYRt2'},
#  {'CYTBD', 'EX_lac__D_e', 'PDH', 'PYRt2'},
#  {'CYTBD', 'LDH_D', 'PDH', 'PYRt2'},
#  {'ACALDt', 'CO2t', 'EX_etoh_e', 'EX_o2_e'},
#  {'CO2t', 'EX_acald_e', 'EX_etoh_e', 'EX_o2_e'},
#  {'ADK1', 'LDH_D', 'PDH', 'PYRt2'},
#  {'ATPS4r', 'LDH_D', 'PDH', 'PYRt2'},
#  {'LDH_D', 'O2t', 'PDH', 'PYRt2'},
#  {'LDH_D', 'PDH', 'PPS', 'PYRt2'},
#  {'EX_o2_e', 'LDH_D', 'PDH', 'PYRt2'},
#  {'FRD7', 'GLNS', 'MALS', 'NADTRHD'},
#  {'EX_pi_e', 'FRD7', 'MALS', 'NADTRHD'},
#  {'EX_nh4_e', 'FRD7', 'MALS', 'NADTRHD'},
#  {'FRD7', 'MALS', 'NADTRHD', 'PIt2r'},
#  {'FRD7', 'MALS', 'NADTRHD', 'RPI'},
#  {'ACALDt', 'ETOHt2r', 'EX_co2_e', 'EX_o2_e'},
#  {'ETOHt2r', 'EX_acald_e', 'EX_co2_e', 'EX_o2_e'},
#  {'FRD7', 'MALS', 'NADTRHD', 'NH4t'},
#  {'ACALDt', 'EX_co2_e', 'EX_etoh_e', 'EX_o2_e'},
#  {'EX_acald_e', 'EX_co2_e', 'EX_etoh_e', 'EX_o2_e'},
#  {'ACALDt', 'ALCD2x', 'EX_co2_e', 'EX_o2_e'},
#  {'ALCD2x', 'EX_acald_e', 'EX_co2_e', 'EX_o2_e'},
#  {'EX_nh4_e', 'GLUN', 'MALS', 'MDH', 'NADTRHD'},
#  {'FUM', 'ME1', 'NADTRHD', 'NH4t', 'PYK'},
#  {'ACALD', 'LDH_D', 'O2t', 'PTAr', 'PYRt2'},
#  {'ACALD', 'CYTBD', 'D_LACt2', 'PPS', 'PYRt2'},
#  {'ACALDt', 'ACONTb', 'EX_pyr_e', 'PTAr', 'TKT1'},
#  {'ACALDt', 'ACONTb', 'EX_ac_e', 'EX_pyr_e', 'TKT1'},
#  {'ACONTb', 'EX_ac_e', 'EX_acald_e', 'EX_pyr_e', 'TKT1'},
#  {'ACALD', 'ACKr', 'CYTBD', 'D_LACt2', 'PYRt2'},
#  {'ACALDt', 'ACONTb', 'ACt2r', 'EX_pyr_e', 'TKT1'},
#  {'ACALDt', 'ACONTb', 'EX_ac_e', 'PYRt2', 'TKT1'},
#  {'ACALDt', 'ACKr', 'ACONTb', 'EX_pyr_e', 'NADTRHD'},
#  {'ACKr', 'ACONTb', 'EX_acald_e', 'EX_pyr_e', 'NADTRHD'},
#  {'ACALD', 'ACKr', 'CYTBD', 'EX_lac__D_e', 'PYRt2'},
#  {'ACALDt', 'ACKr', 'ACONTb', 'EX_pyr_e', 'TKT1'},
#  {'ACALD', 'ACKr', 'ACONTb', 'EX_pyr_e', 'TKT1'},
#  {'ACALDt', 'ACONTb', 'EX_ac_e', 'PYRt2', 'TKT2'},
#  {'ACALD', 'ACONTb', 'EX_ac_e', 'PYRt2', 'TKT2'},
#  {'ACONTb', 'EX_ac_e', 'EX_acald_e', 'PYRt2', 'TKT2'},
#  {'ACALDt', 'ACKr', 'ACONTb', 'GND', 'PYRt2'},
#  {'ACKr', 'ACONTb', 'EX_acald_e', 'GND', 'PYRt2'},
#  {'ACALD', 'ACONTb', 'ACt2r', 'EX_pyr_e', 'TKT1'},
#  {'ACONTb', 'EX_ac_e', 'EX_acald_e', 'PYRt2', 'TKT1'},
#  {'ACALDt', 'ACONTb', 'G6PDH2r', 'PTAr', 'PYRt2'},
#  {'ACONTb', 'EX_acald_e', 'G6PDH2r', 'PTAr', 'PYRt2'},
#  {'ACALDt', 'ACKr', 'ACONTb', 'ICDHyr', 'PYRt2', 'RPI'},
#  {'ACALDt', 'ACKr', 'ACONTb', 'PYRt2', 'TKT1'},
#  {'ACALD', 'ACKr', 'ACONTb', 'PYRt2', 'RPI'},
#  {'ACALD', 'ACKr', 'ACONTb', 'PYRt2', 'TKT1'},
#  {'ACALD', 'ACONTb', 'EX_ac_e', 'EX_pyr_e', 'TKT1'},
#  {'ACALDt', 'ACONTa', 'EX_ac_e', 'EX_pyr_e', 'TALA'},
#  {'ACALDt', 'ACONTa', 'EX_ac_e', 'EX_pyr_e', 'GND'},
#  {'ACONTa', 'EX_ac_e', 'EX_acald_e', 'EX_pyr_e', 'GND'},
#  {'ACALDt', 'ACONTa', 'EX_ac_e', 'EX_pyr_e', 'MALS', 'TKT1'},
#  {'ACALDt', 'ACONTb', 'PTAr', 'PYRt2', 'TKT1'},
#  {'ACALDt', 'ACONTb', 'EX_ac_e', 'EX_pyr_e', 'G6PDH2r'},
#  {'ACONTb', 'EX_ac_e', 'EX_acald_e', 'EX_pyr_e', 'G6PDH2r'},
#  {'ACALD', 'ACONTb', 'EX_ac_e', 'EX_pyr_e', 'G6PDH2r'},
#  {'ACALDt', 'ACKr', 'ACONTb', 'EX_pyr_e', 'G6PDH2r'},
#  {'ACKr', 'ACONTb', 'EX_acald_e', 'EX_pyr_e', 'G6PDH2r', 'MALS'},
#  {'ACALD', 'ACKr', 'ACONTb', 'EX_pyr_e', 'G6PDH2r'},
#  {'ACALDt', 'ACONTb', 'NADTRHD', 'PTAr', 'PYRt2'},
#  {'ACONTb', 'EX_acald_e', 'NADTRHD', 'PTAr', 'PYRt2'},
#  {'ACALDt', 'ACONTb', 'EX_ac_e', 'NADTRHD', 'PYRt2'},
#  {'ACONTb', 'EX_ac_e', 'EX_acald_e', 'NADTRHD', 'PYRt2'},
#  {'ACALDt', 'ACONTb', 'ACt2r', 'EX_pyr_e', 'G6PDH2r'},
#  {'ACALD', 'ACONTb', 'ACt2r', 'EX_pyr_e', 'G6PDH2r'},
#  {'ACALDt', 'ACKr', 'ACONTb', 'PYRt2', 'TALA'},
#  {'ACKr', 'ACONTb', 'EX_acald_e', 'PYRt2', 'TALA'},
#  {'ACKr', 'ACONTb', 'EX_acald_e', 'PYRt2', 'RPI'},
#  {'ACALDt', 'ACONTb', 'ACt2r', 'PYRt2', 'TALA'},
#  {'ACALDt', 'ACONTb', 'ACt2r', 'PYRt2', 'RPI'},
#  {'ACONTb', 'ACt2r', 'EX_acald_e', 'PYRt2', 'RPI'},
#  {'ACALDt', 'ACONTb', 'ACt2r', 'PYRt2', 'TKT2'},
#  {'ACALD', 'ACONTb', 'ACt2r', 'PYRt2', 'TKT2'},
#  {'ACONTb', 'ACt2r', 'EX_acald_e', 'PYRt2', 'TKT2'},
#  {'ACALDt', 'ACONTa', 'EX_ac_e', 'PYRt2', 'TKT1'},
#  {'ACALD', 'ACONTa', 'EX_ac_e', 'EX_pyr_e', 'GND'},
#  {'ACALDt', 'ACONTa', 'EX_ac_e', 'EX_pyr_e', 'G6PDH2r'},
#  {'ACONTa', 'EX_ac_e', 'EX_acald_e', 'EX_pyr_e', 'G6PDH2r'},
#  {'ACALD', 'ACONTa', 'EX_ac_e', 'EX_pyr_e', 'G6PDH2r'},
#  {'ACALDt', 'ACONTa', 'EX_ac_e', 'G6PDH2r', 'PYRt2'},
#  {'ACONTa', 'EX_ac_e', 'EX_acald_e', 'G6PDH2r', 'PYRt2'},
#  {'ACALDt', 'ACONTb', 'PTAr', 'PYRt2', 'TALA'},
#  {'ACALD', 'ACONTb', 'PTAr', 'PYRt2', 'TALA'},
#  {'ACONTb', 'EX_acald_e', 'PTAr', 'PYRt2', 'TALA'},
#  {'ACALDt', 'ACONTa', 'PTAr', 'PYRt2', 'TKT1'},
#  {'ACONTa', 'EX_acald_e', 'PTAr', 'PYRt2', 'TKT1'},
#  {'ACALDt', 'ACKr', 'CS', 'G6PDH2r', 'PYRt2'},
#  {'ACKr', 'CS', 'EX_acald_e', 'G6PDH2r', 'PYRt2'},
#  {'ACALD', 'ACKr', 'ACONTb', 'GND', 'PYRt2'},
#  {'ACALDt', 'ACONTb', 'ACt2r', 'PYRt2', 'TKT1'},
#  {'ACONTb', 'ACt2r', 'EX_acald_e', 'PYRt2', 'TKT1'},
#  {'ACALD', 'ACONTb', 'ACt2r', 'PYRt2', 'TKT1'},
#  {'ACALD', 'ACONTb', 'ACt2r', 'PYRt2', 'RPI'},
#  {'ACALD', 'ACKr', 'ACONTb', 'EX_pyr_e', 'NADTRHD'},
#  {'ACALDt', 'ACONTa', 'ACt2r', 'EX_pyr_e', 'NADTRHD'},
#  {'ACONTa', 'ACt2r', 'EX_acald_e', 'EX_pyr_e', 'NADTRHD'},
#  {'ACALDt', 'ACONTa', 'ACt2r', 'NADTRHD', 'PYRt2'},
#  {'ACONTa', 'ACt2r', 'EX_acald_e', 'NADTRHD', 'PYRt2'},
#  {'ACALDt', 'ACONTb', 'ACt2r', 'G6PDH2r', 'PYRt2'},
#  {'ACONTb', 'ACt2r', 'EX_acald_e', 'G6PDH2r', 'PYRt2'},
#  {'ACALD', 'ACONTa', 'ACt2r', 'NADTRHD', 'PYRt2'},
#  {'ACALD', 'ACONTa', 'EX_ac_e', 'G6PDH2r', 'PYRt2'},
#  {'ACALDt', 'ACONTa', 'EX_ac_e', 'EX_pyr_e', 'TKT2'},
#  {'ACONTa', 'EX_ac_e', 'EX_acald_e', 'EX_pyr_e', 'TKT2'},
#  {'ACALDt', 'ACONTb', 'EX_pyr_e', 'PTAr', 'RPI'},
#  {'ACONTb', 'EX_acald_e', 'EX_pyr_e', 'PTAr', 'RPI'},
#  {'ACALD', 'ACONTb', 'EX_pyr_e', 'PTAr', 'RPI'},
#  {'ACALD', 'ACONTa', 'EX_ac_e', 'EX_pyr_e', 'TKT2'},
#  {'ACALDt', 'ACONTb', 'EX_ac_e', 'EX_pyr_e', 'ICDHyr', 'RPI'},
#  {'ACALDt', 'ACONTb', 'EX_ac_e', 'G6PDH2r', 'PYRt2'},
#  {'ACONTb', 'EX_ac_e', 'EX_acald_e', 'G6PDH2r', 'PYRt2'},
#  {'ACALD', 'ACONTb', 'G6PDH2r', 'PTAr', 'PYRt2'},
#  {'ACALD', 'ACKr', 'ACONTb', 'PYRt2', 'TALA'},
#  {'ACALDt', 'ACONTa', 'ACt2r', 'GND', 'PYRt2'},
#  {'ACONTa', 'ACt2r', 'EX_acald_e', 'GND', 'PYRt2'},
#  {'ACALDt', 'ACONTa', 'ACt2r', 'PYRt2', 'TKT1'},
#  {'ACALD', 'ACONTa', 'ACt2r', 'PYRt2', 'TKT1'},
#  {'ACONTb', 'ACt2r', 'EX_acald_e', 'PYRt2', 'TALA'},
#  {'ACONTa', 'EX_ac_e', 'EX_acald_e', 'EX_pyr_e', 'TKT1'},
#  {'ACALDt', 'ACONTb', 'EX_ac_e', 'EX_pyr_e', 'GND'},
#  {'ACONTb', 'EX_ac_e', 'EX_acald_e', 'EX_pyr_e', 'GND'},
#  {'ACALDt', 'ACONTb', 'EX_ac_e', 'GND', 'PYRt2'},
#  {'ACONTb', 'EX_ac_e', 'EX_acald_e', 'GND', 'PYRt2'},
#  {'ACALDt', 'ACONTb', 'ACt2r', 'NADTRHD', 'PYRt2'},
#  {'ACALD', 'ACONTb', 'ACt2r', 'NADTRHD', 'PYRt2'},
#  {'ACALDt', 'ACONTa', 'PTAr', 'PYRt2', 'RPE'},
#  {'ACONTa', 'EX_acald_e', 'PTAr', 'PYRt2', 'RPE'},
#  {'ACALD', 'ACONTa', 'PTAr', 'PYRt2', 'RPE'},
#  {'ACALDt', 'ACONTa', 'EX_pyr_e', 'PTAr', 'RPE'},
#  {'ACONTa', 'EX_acald_e', 'EX_pyr_e', 'PTAr', 'RPE'},
#  {'ACALDt', 'ACONTb', 'EX_pyr_e', 'PTAr', 'TALA'},
#  {'ACALDt', 'ACONTb', 'ACt2r', 'EX_pyr_e', 'TALA'},
#  {'ACALDt', 'ACKr', 'CS', 'EX_pyr_e', 'G6PDH2r'},
#  {'ACALD', 'ACKr', 'CS', 'EX_pyr_e', 'G6PDH2r'},
#  {'ACONTb', 'ACt2r', 'EX_acald_e', 'EX_pyr_e', 'G6PDH2r'},
#  {'ACALD', 'ACt2r', 'CYTBD', 'LDH_D', 'PYRt2'},
#  {'ACALD', 'ACt2r', 'CYTBD', 'D_LACt2', 'PYRt2'},
#  {'ACALDt', 'ACONTa', 'PGL', 'PTAr', 'PYRt2'},
#  {'ACONTa', 'EX_acald_e', 'PGL', 'PTAr', 'PYRt2'},
#  {'ACALD', 'ACONTa', 'ACt2r', 'EX_pyr_e', 'NADTRHD'},
#  {'ACALDt', 'ACONTb', 'ACt2r', 'GND', 'PYRt2'},
#  {'ACONTb', 'ACt2r', 'EX_acald_e', 'GND', 'PYRt2'},
#  {'ACALDt', 'ACONTa', 'ACt2r', 'EX_pyr_e', 'TKT1'},
#  {'ACALDt', 'ACKr', 'ACONTb', 'NADTRHD', 'PYRt2'},
#  {'ACALD', 'ACONTa', 'ACt2r', 'EX_pyr_e', 'TKT1'},
#  {'ACKr', 'ACONTb', 'EX_acald_e', 'NADTRHD', 'PYRt2'},
#  {'ACALD', 'ACONTb', 'ACt2r', 'G6PDH2r', 'PYRt2'},
#  {'ACALDt', 'ACONTa', 'EX_ac_e', 'PYRt2', 'TALA'},
#  {'ACALD', 'ACONTb', 'EX_ac_e', 'NADTRHD', 'PYRt2'},
#  {'ACALD', 'ACONTb', 'EX_ac_e', 'G6PDH2r', 'PYRt2'},
#  {'ACALDt', 'ACONTa', 'EX_ac_e', 'PYRt2', 'TKT2'},
#  {'ACALD', 'ACONTa', 'EX_ac_e', 'PYRt2', 'TKT2'},
#  {'ACALDt', 'ACONTa', 'ACt2r', 'PGL', 'PYRt2'},
#  {'ACONTa', 'ACt2r', 'EX_acald_e', 'PGL', 'PYRt2'},
#  {'ACALD', 'ACONTa', 'ACt2r', 'PGL', 'PYRt2'},
#  {'ACALDt', 'ACONTa', 'ACt2r', 'PYRt2', 'RPE'},
#  {'ACALD', 'ACONTa', 'ACt2r', 'PYRt2', 'RPE'},
#  {'ACONTa', 'ACt2r', 'EX_acald_e', 'PYRt2', 'RPE'},
#  {'ACONTa', 'ACt2r', 'EX_acald_e', 'EX_pyr_e', 'RPE'},
#  {'ACALDt', 'ACONTa', 'ACt2r', 'PYRt2', 'TALA'},
#  {'ACALDt', 'ACONTa', 'ACt2r', 'EX_pyr_e', 'TALA'},
#  {'ACONTa', 'ACt2r', 'EX_acald_e', 'PYRt2', 'TALA'},
#  {'ACALD', 'ACONTa', 'PTAr', 'PYRt2', 'TKT1'},
#  {'ACALD', 'ACONTa', 'ACt2r', 'PYRt2', 'TALA'},
#  {'ACALDt', 'ACONTb', 'GND', 'PTAr', 'PYRt2'},
#  {'ACONTb', 'EX_acald_e', 'GND', 'PTAr', 'PYRt2'},
#  {'ACALDt', 'ACONTa', 'ACt2r', 'G6PDH2r', 'PYRt2'},
#  {'ACONTa', 'ACt2r', 'EX_acald_e', 'G6PDH2r', 'PYRt2'},
#  {'ACALDt', 'ACONTa', 'ACt2r', 'EX_pyr_e', 'G6PDH2r'},
#  {'ACONTa', 'ACt2r', 'EX_acald_e', 'EX_pyr_e', 'G6PDH2r'},
#  {'ACALD', 'ACONTa', 'ACt2r', 'EX_pyr_e', 'G6PDH2r'},
#  {'ACALD', 'ACONTa', 'ACt2r', 'G6PDH2r', 'PYRt2'},
#  {'ACALDt', 'ACONTa', 'ACt2r', 'EX_pyr_e', 'GND'},
#  {'ACONTa', 'ACt2r', 'EX_acald_e', 'EX_pyr_e', 'GND'},
#  {'ACALD', 'ACONTa', 'ACt2r', 'EX_pyr_e', 'GND'},
#  {'ACALDt', 'ACONTa', 'G6PDH2r', 'PTAr', 'PYRt2'},
#  {'ACONTa', 'EX_acald_e', 'G6PDH2r', 'PTAr', 'PYRt2'},
#  {'ACALDt', 'ACONTa', 'EX_pyr_e', 'G6PDH2r', 'PTAr'},
#  {'ACONTa', 'EX_acald_e', 'EX_pyr_e', 'G6PDH2r', 'PTAr'},
#  {'ACALD', 'ACONTa', 'G6PDH2r', 'PTAr', 'PYRt2'},
#  {'ACALD', 'ADK1', 'D_LACt2', 'EX_pyr_e', 'O2t'},
#  {'ACALDt', 'ACONTb', 'EX_ac_e', 'PYRt2', 'TALA'},
#  {'ACONTb', 'EX_ac_e', 'EX_acald_e', 'PYRt2', 'TALA'},
#  {'ACALD', 'ACONTb', 'EX_pyr_e', 'PTAr', 'TALA'},
#  {'ACALD', 'ACONTa', 'EX_ac_e', 'EX_pyr_e', 'TKT1'},
#  {'ACALD', 'ACONTa', 'EX_pyr_e', 'PTAr', 'RPE'},
#  {'ACALD', 'ACONTb', 'EX_ac_e', 'EX_pyr_e', 'GND'},
#  {'ACALDt', 'ACKr', 'CS', 'PYRt2', 'RPE'},
#  {'ACALDt', 'ACKr', 'CS', 'EX_pyr_e', 'RPE'},
#  {'ACKr', 'CS', 'EX_acald_e', 'PYRt2', 'RPE'},
#  {'ACALD', 'ACKr', 'CYTBD', 'LDH_D', 'PYRt2'},
#  {'ACALD', 'ACKr', 'CS', 'PYRt2', 'RPE'},
#  {'ACKr', 'CS', 'EX_acald_e', 'EX_pyr_e', 'RPE'},
#  {'ACONTb', 'EX_ac_e', 'EX_acald_e', 'EX_pyr_e', 'RPI'},
#  {'ACALDt', 'ACKr', 'ACONTa', 'EX_pyr_e', 'NADTRHD'},
#  {'ACKr', 'ACONTa', 'EX_acald_e', 'EX_pyr_e', 'NADTRHD'},
#  {'ACONTb', 'ACt2r', 'EX_acald_e', 'EX_pyr_e', 'TALA'},
#  {'ACALDt', 'ACKr', 'ACONTa', 'NADTRHD', 'PYRt2'},
#  {'ACKr', 'ACONTa', 'EX_acald_e', 'NADTRHD', 'PYRt2'},
#  {'ACALD', 'ACKr', 'ACONTa', 'NADTRHD', 'PYRt2'},
#  {'ACALD', 'ACONTb', 'ACt2r', 'EX_pyr_e', 'TALA'},
#  {'ACALD', 'EX_lac__D_e', 'O2t', 'PPS', 'PYRt2'},
#  {'ACALD', 'ACt2r', 'EX_lac__D_e', 'O2t', 'PYRt2'},
#  {'ACKr', 'ACONTb', 'EX_acald_e', 'EX_pyr_e', 'TKT1'},
#  {'ACONTb', 'EX_acald_e', 'EX_pyr_e', 'PTAr', 'TALA'},
#  {'ACALD', 'ADK1', 'CYTBD', 'EX_lac__D_e', 'PYRt2'},
#  {'ACALDt', 'ACKr', 'CS', 'PGL', 'PYRt2'},
#  {'ACKr', 'CS', 'EX_acald_e', 'PGL', 'PYRt2'},
#  {'ACALDt', 'ACKr', 'CS', 'EX_pyr_e', 'PGL'},
#  {'ACKr', 'CS', 'EX_acald_e', 'EX_pyr_e', 'PGL'},
#  {'ACALD', 'ACKr', 'CS', 'EX_pyr_e', 'PGL'},
#  {'ACONTa', 'EX_ac_e', 'EX_acald_e', 'PYRt2', 'TKT2'},
#  {'ACALD', 'ACONTa', 'ACt2r', 'GND', 'PYRt2'},
#  {'ATPS4r', 'FRD7', 'SUCCt2_2', 'THD2', 'TKT1'},
#  {'ATPS4r', 'FRD7', 'SUCCt2_2', 'TALA', 'THD2'},
#  {'ATPS4r', 'EX_pi_e', 'FRD7', 'SUCCt2_2', 'THD2'},
#  {'ACONTb', 'ACt2r', 'EX_acald_e', 'EX_pyr_e', 'TKT1'},
#  {'ACALD', 'ACONTb', 'EX_ac_e', 'EX_pyr_e', 'RPI'},
#  {'ACALDt', 'CS', 'EX_ac_e', 'EX_pyr_e', 'RPE'},
#  {'ACALDt', 'CS', 'EX_ac_e', 'EX_pyr_e', 'TALA'},
#  {'CS', 'EX_ac_e', 'EX_acald_e', 'EX_pyr_e', 'TALA'},
#  {'ACALDt', 'CS', 'EX_ac_e', 'EX_pyr_e', 'TKT1'},
#  {'CS', 'EX_ac_e', 'EX_acald_e', 'EX_pyr_e', 'TKT1'},
#  {'ACALD', 'CS', 'EX_ac_e', 'EX_pyr_e', 'TKT1'},
#  {'ACALDt', 'CS', 'EX_ac_e', 'EX_pyr_e', 'GND'},
#  {'ACONTa', 'ACt2r', 'EX_acald_e', 'EX_pyr_e', 'TALA'},
#  {'ACALD', 'ACONTb', 'NADTRHD', 'PTAr', 'PYRt2'},
#  {'ACALDt', 'ACONTa', 'PTAr', 'PYRt2', 'RPI'},
#  {'ACONTa', 'EX_acald_e', 'PTAr', 'PYRt2', 'RPI'},
#  {'ACALD', 'ACONTa', 'PTAr', 'PYRt2', 'RPI'},
#  {'ACALD', 'ACONTa', 'EX_ac_e', 'EX_pyr_e', 'TALA'},
#  {'ACALD', 'ACONTa', 'EX_ac_e', 'PYRt2', 'TKT1'},
#  {'ACALD', 'ACONTb', 'EX_ac_e', 'PYRt2', 'TALA'},
#  {'ACALD', 'EX_lac__D_e', 'O2t', 'PTAr', 'PYRt2'},
#  {'ACALD', 'ADK1', 'CYTBD', 'LDH_D', 'PYRt2'},
#  {'ACALD', 'ADK1', 'CYTBD', 'D_LACt2', 'PYRt2'},
#  {'ACALD', 'D_LACt2', 'EX_pyr_e', 'O2t', 'PPS'},
#  {'ACALDt', 'ACKr', 'CS', 'PYRt2', 'RPI'},
#  {'ACALDt', 'ACKr', 'CS', 'EX_pyr_e', 'RPI'},
#  {'ACKr', 'CS', 'EX_acald_e', 'PYRt2', 'RPI'},
#  {'ACALDt', 'ACONTa', 'ACt2r', 'PYRt2', 'TKT2'},
#  {'ACONTa', 'ACt2r', 'EX_acald_e', 'PYRt2', 'TKT2'},
#  {'ACALD', 'ADK1', 'EX_pyr_e', 'LDH_D', 'O2t'},
#  {'ACALD', 'EX_pyr_e', 'LDH_D', 'O2t', 'PPS'},
#  {'ACALDt', 'ACONTa', 'ACt2r', 'EX_pyr_e', 'TKT2'},
#  {'ACALD', 'ACONTa', 'ACt2r', 'EX_pyr_e', 'TKT2'},
#  {'ACALD', 'ACONTa', 'ACt2r', 'PYRt2', 'TKT2'},
#  {'ACALD', 'ACKr', 'EX_pyr_e', 'LDH_D', 'O2t'},
#  {'ACONTa', 'ACt2r', 'EX_acald_e', 'EX_pyr_e', 'TKT2'},
#  {'ATPS4r', 'FRD7', 'PYK', 'SUCCt2_2', 'THD2'},
#  {'CS', 'EX_ac_e', 'EX_acald_e', 'EX_pyr_e', 'RPE'},
#  {'CS', 'EX_ac_e', 'EX_acald_e', 'PYRt2', 'RPE'},
#  {'ACALD', 'ACKr', 'EX_lac__D_e', 'O2t', 'PYRt2'},
#  {'ACALD', 'ACONTb', 'EX_ac_e', 'GND', 'PYRt2'},
#  {'FRD7', 'GND', 'ICL', 'NADTRHD', 'TKT1'},
#  {'CS', 'EX_ac_e', 'EX_acald_e', 'EX_pyr_e', 'GND'},
#  {'ATPS4r', 'D_LACt2', 'FRD7', 'NADTRHD', 'SUCCt2_2'},
#  {'ATPS4r', 'FRD7', 'LDH_D', 'SUCCt2_2', 'THD2'},
#  {'ACALDt', 'ACONTa', 'EX_ac_e', 'EX_pyr_e', 'NADTRHD'},
#  {'ACONTa', 'EX_ac_e', 'EX_acald_e', 'EX_pyr_e', 'NADTRHD'},
#  {'ACALD', 'ACONTa', 'EX_ac_e', 'EX_pyr_e', 'NADTRHD'},
#  {'ATPS4r', 'D_LACt2', 'FRD7', 'SUCCt2_2', 'THD2'},
#  {'ACALD', 'ACONTa', 'PGL', 'PTAr', 'PYRt2'},
#  {'ACALDt', 'ACKr', 'ACONTa', 'PYRt2', 'RPE'},
#  {'ACKr', 'ACONTa', 'EX_acald_e', 'PYRt2', 'RPE'},
#  {'ACALD', 'ACKr', 'ACONTa', 'PYRt2', 'RPE'},
#  {'ACALDt', 'ACKr', 'ACONTa', 'PYRt2', 'TKT1'},
#  {'ACKr', 'ACONTa', 'EX_acald_e', 'PYRt2', 'TKT1'},
#  {'ACALD', 'ACKr', 'CS', 'G6PDH2r', 'PYRt2'},
#  {'ACALDt', 'CS', 'EX_ac_e', 'EX_pyr_e', 'TKT2'},
#  {'CS', 'EX_ac_e', 'EX_acald_e', 'EX_pyr_e', 'TKT2'},
#  {'ACALD', 'CS', 'EX_ac_e', 'EX_pyr_e', 'TKT2'},
#  {'ACALD', 'ACKr', 'ACONTb', 'NADTRHD', 'PYRt2'},
#  {'ACALD', 'ACKr', 'CS', 'PGL', 'PYRt2'},
#  {'ACALDt', 'CS', 'EX_ac_e', 'EX_pyr_e', 'PGL'},
#  {'CS', 'EX_ac_e', 'EX_acald_e', 'EX_pyr_e', 'PGL'},
#  {'ACALDt', 'CS', 'EX_ac_e', 'PGL', 'PYRt2'},
#  {'CS', 'EX_ac_e', 'EX_acald_e', 'PGL', 'PYRt2'},
#  {'ACALD', 'CS', 'EX_ac_e', 'EX_pyr_e', 'PGL'},
#  {'ACALD', 'CS', 'EX_ac_e', 'PGL', 'PYRt2'},
#  {'ACALD', 'ACt2r', 'EX_pyr_e', 'LDH_D', 'O2t'},
#  {'ACALD', 'ACONTa', 'EX_ac_e', 'PYRt2', 'TALA'},
#  {'ACALDt', 'ACONTb', 'EX_pyr_e', 'GND', 'PTAr'},
#  {'ACONTb', 'EX_acald_e', 'EX_pyr_e', 'GND', 'PTAr'},
#  {'ACALD', 'ACONTb', 'EX_pyr_e', 'GND', 'PTAr'},
#  {'ACALD', 'ACONTb', 'ACt2r', 'PYRt2', 'TALA'},
#  {'ATPS4r', 'FRD7', 'ICDHyr', 'NADTRHD', 'SUCCt2_2'},
#  {'ATPS4r', 'EX_pi_e', 'FRD7', 'NADTRHD', 'SUCCt2_2'},
#  {'ATPS4r', 'EX_nh4_e', 'FRD7', 'NADTRHD', 'SUCCt2_2'},
#  {'ACALDt', 'ACONTb', 'ACt2r', 'EX_pyr_e', 'RPE'},
#  {'ACONTb', 'ACt2r', 'EX_acald_e', 'EX_pyr_e', 'RPE'},
#  {'ACALD', 'ACONTb', 'ACt2r', 'EX_pyr_e', 'RPE'},
#  {'ATPS4r', 'EX_lac__D_e', 'FRD7', 'SUCCt2_2', 'THD2'},
#  {'ACALDt', 'ACONTa', 'EX_ac_e', 'NADTRHD', 'PYRt2'},
#  {'ACONTa', 'EX_ac_e', 'EX_acald_e', 'NADTRHD', 'PYRt2'},
#  {'ACALD', 'ACONTa', 'EX_ac_e', 'NADTRHD', 'PYRt2'},
#  {'ATPS4r', 'EX_lac__D_e', 'FRD7', 'NADTRHD', 'SUCCt2_2'},
#  {'ACALD', 'ACKr', 'D_LACt2', 'EX_pyr_e', 'O2t'},
#  {'ACONTb', 'EX_acald_e', 'PTAr', 'PYRt2', 'TKT1'},
#  {'ACALD', 'ACKr', 'CS', 'EX_pyr_e', 'RPE'},
#  {'ACALDt', 'ACKr', 'ACONTa', 'G6PDH2r', 'PYRt2'},
#  {'ACKr', 'ACONTa', 'EX_acald_e', 'G6PDH2r', 'PYRt2'},
#  {'ACALD', 'ACKr', 'ACONTa', 'G6PDH2r', 'PYRt2'},
#  {'ACALDt', 'ACKr', 'ACONTa', 'EX_pyr_e', 'PGL'},
#  {'ACKr', 'ACONTa', 'EX_acald_e', 'EX_pyr_e', 'PGL'},
#  {'ACALDt', 'ACKr', 'ACONTa', 'EX_pyr_e', 'GND'},
#  {'ACKr', 'ACONTa', 'EX_acald_e', 'EX_pyr_e', 'GND'},
#  {'ACALDt', 'ACKr', 'ACONTa', 'EX_pyr_e', 'TKT2'},
#  {'ACKr', 'ACONTa', 'EX_acald_e', 'EX_pyr_e', 'TKT2'},
#  {'ACALD', 'ACKr', 'ACONTa', 'EX_pyr_e', 'TKT2'},
#  {'ACALDt', 'ACKr', 'ACONTa', 'EX_pyr_e', 'TALA'},
#  {'FRD7', 'GND', 'ICL', 'NADTRHD', 'TALA'},
#  {'ACALDt', 'ACKr', 'ACONTb', 'EX_pyr_e', 'TALA'},
#  {'ACALDt', 'ACONTa', 'ACt2r', 'MALS', 'PYRt2', 'RPI'},
#  {'ACALD', 'ACKr', 'CS', 'PYRt2', 'RPI'},
#  {'ACALDt', 'ACONTb', 'ACt2r', 'EX_pyr_e', 'ICDHyr', 'RPI'},
#  {'ACALD', 'ACONTb', 'ACt2r', 'EX_pyr_e', 'RPI'},
#  {'ACALD', 'ACONTa', 'ACt2r', 'PYRt2', 'RPI'},
#  {'ACALD', 'ACKr', 'ACONTb', 'EX_pyr_e', 'TALA'},
#  {'ACONTa', 'ACt2r', 'EX_acald_e', 'PYRt2', 'RPI'},
#  {'ACALD', 'ACONTa', 'EX_pyr_e', 'G6PDH2r', 'PTAr'},
#  {'ACALDt', 'ACONTa', 'EX_pyr_e', 'PTAr', 'RPI'},
#  {'ACONTa', 'EX_acald_e', 'EX_pyr_e', 'MALS', 'PTAr', 'RPI'},
#  {'FRD7', 'GND', 'MALS', 'NADTRHD', 'TKT1'},
#  {'FRD7', 'GND', 'MALS', 'NADTRHD', 'TALA'},
#  {'FRD7', 'ICL', 'NADTRHD', 'TALA', 'TKT2'},
#  {'FRD7', 'MALS', 'NADTRHD', 'RPE', 'TKT1'},
#  {'FRD7', 'ICDHyr', 'ME1', 'NADTRHD', 'PYK'},
#  {'EX_nh4_e', 'FRD7', 'ME1', 'NADTRHD', 'PYK'},
#  {'ACALDt', 'ACKr', 'ACONTa', 'GND', 'PYRt2'},
#  {'ACKr', 'ACONTa', 'EX_acald_e', 'GND', 'PYRt2'},
#  {'FRD7', 'ME1', 'NADTRHD', 'PIt2r', 'PYK'},
#  {'BIOMASS_Ecoli_core_w_GAM', 'FRD7', 'ME1', 'NADTRHD', 'PYK'},
#  {'EX_pi_e', 'FRD7', 'ME1', 'NADTRHD', 'PYK'},
#  {'FRD7', 'MALS', 'NADTRHD', 'TKT1', 'TKT2'},
#  {'FRD7', 'MALS', 'NADTRHD', 'TALA', 'TKT2'},
#  {'FRD7', 'GLUDy', 'GLUSy', 'ICL', 'NADTRHD'},
#  {'FRD7', 'ICL', 'NADTRHD', 'RPE', 'TKT1'},
#  {'FRD7', 'ICL', 'NADTRHD', 'RPE', 'TALA'},
#  {'ACALD', 'ACKr', 'ACONTa', 'GND', 'PYRt2'},
#  {'ACALD', 'ACKr', 'LDH_D', 'O2t', 'PYRt2'},
#  {'ACALDt', 'CS', 'EX_ac_e', 'PYRt2', 'TKT2'},
#  {'CS', 'EX_ac_e', 'EX_acald_e', 'PYRt2', 'TKT2'},
#  {'ACALD', 'CS', 'EX_ac_e', 'PYRt2', 'TKT2'},
#  {'ACALDt', 'CS', 'EX_ac_e', 'GND', 'PYRt2'},
#  {'CS', 'EX_ac_e', 'EX_acald_e', 'GND', 'PYRt2'},
#  {'ACALD', 'EX_pyr_e', 'LDH_D', 'O2t', 'PTAr'},
#  {'ACONTa', 'EX_ac_e', 'EX_acald_e', 'PYRt2', 'TKT1'},
#  {'ACALDt', 'ACONTa', 'ACt2r', 'EX_pyr_e', 'RPE'},
#  {'ACALD', 'ACONTa', 'ACt2r', 'EX_pyr_e', 'RPE'},
#  {'ACALD', 'CS', 'EX_ac_e', 'EX_pyr_e', 'RPE'},
#  {'ACALD', 'ACKr', 'ACONTa', 'EX_pyr_e', 'NADTRHD'},
#  {'ACALDt', 'ACONTb', 'EX_ac_e', 'EX_pyr_e', 'TALA'},
#  {'ACONTb', 'EX_ac_e', 'EX_acald_e', 'EX_pyr_e', 'TALA'},
#  {'ATPS4r', 'FRD7', 'NADTRHD', 'RPI', 'SUCCt2_2'},
#  {'ACALD', 'ADK1', 'EX_lac__D_e', 'EX_pyr_e', 'O2t'},
#  {'ACALD', 'EX_lac__D_e', 'EX_pyr_e', 'O2t', 'PPS'},
#  {'ACALD', 'ACt2r', 'EX_lac__D_e', 'EX_pyr_e', 'O2t'},
#  {'ACALD', 'EX_lac__D_e', 'EX_pyr_e', 'O2t', 'PTAr'},
#  {'ACALDt', 'ACKr', 'ACONTa', 'EX_pyr_e', 'RPE'},
#  {'ACALDt', 'ACONTb', 'ACt2r', 'PYRt2', 'RPE'},
#  {'ACONTb', 'ACt2r', 'EX_acald_e', 'PYRt2', 'RPE'},
#  {'ACALDt', 'ACONTb', 'EX_ac_e', 'ICL', 'PYRt2', 'RPE'},
#  {'ACONTb', 'EX_ac_e', 'EX_acald_e', 'ICL', 'PYRt2', 'RPE'},
#  {'ACALD', 'ACONTb', 'ACt2r', 'PYRt2', 'RPE'},
#  {'ACALDt', 'ACKr', 'ACONTb', 'PYRt2', 'RPE'},
#  {'ACKr', 'ACONTb', 'EX_acald_e', 'PYRt2', 'RPE'},
#  {'ACALD', 'ACKr', 'ACONTb', 'PYRt2', 'RPE'},
#  {'ACALDt', 'ACONTb', 'ACt2r', 'EX_pyr_e', 'GND'},
#  {'ACONTb', 'ACt2r', 'EX_acald_e', 'EX_pyr_e', 'GND'},
#  {'ACALDt', 'ACONTb', 'PTAr', 'PYRt2', 'RPE'},
#  {'ACONTb', 'EX_acald_e', 'ICL', 'PTAr', 'PYRt2', 'RPE'},
#  {'ACALDt', 'ACONTa', 'EX_pyr_e', 'PGL', 'PTAr'},
#  {'ACONTa', 'EX_acald_e', 'EX_pyr_e', 'PGL', 'PTAr'},
#  {'ACALD', 'D_LACt2', 'EX_pyr_e', 'O2t', 'PTAr'},
#  {'ACALD', 'ACKr', 'ACONTa', 'EX_pyr_e', 'PGL'},
#  {'FRD7', 'ICDHyr', 'MDH', 'ME1', 'NADTRHD'},
#  {'BIOMASS_Ecoli_core_w_GAM', 'FRD7', 'MDH', 'ME1', 'NADTRHD'},
#  {'FRD7', 'MDH', 'ME1', 'NADTRHD', 'PIt2r'},
#  {'FRD7', 'MDH', 'ME1', 'NADTRHD', 'NH4t'},
#  {'FRD7', 'MDH', 'ME1', 'NADTRHD', 'RPI'},
#  {'FRD7', 'GLNS', 'MDH', 'ME1', 'NADTRHD'},
#  {'EX_pi_e', 'FRD7', 'GLUSy', 'MDH', 'ME1', 'NADTRHD'},
#  {'EX_nh4_e', 'FRD7', 'MDH', 'ME1', 'NADTRHD'},
#  {'ACONTa', 'ACt2r', 'EX_acald_e', 'PYRt2', 'TKT1'},
#  {'ACALDt', 'ACONTa', 'ACt2r', 'EX_pyr_e', 'MALS', 'RPI'},
#  {'ACONTa', 'ACt2r', 'EX_acald_e', 'EX_pyr_e', 'RPI'},
#  {'ACALD', 'ADK1', 'D_LACt2', 'EX_o2_e', 'PYRt2'},
#  {'ACALD', 'D_LACt2', 'EX_o2_e', 'EX_pyr_e', 'PTAr'},
#  {'ACALD', 'EX_lac__D_e', 'EX_o2_e', 'EX_pyr_e', 'PTAr'},
#  {'ATPS4r', 'BIOMASS_Ecoli_core_w_GAM', 'FRD7', 'SUCCt2_2', 'THD2'},
#  {'ACALD', 'ACONTa', 'EX_pyr_e', 'PTAr', 'RPI'},
#  {'ACALDt', 'ACONTa', 'PTAr', 'PYRt2', 'TALA'},
#  {'ACONTa', 'EX_acald_e', 'PTAr', 'PYRt2', 'TALA'},
#  {'ACALDt', 'ACONTa', 'EX_pyr_e', 'PTAr', 'TALA'},
#  {'ACONTa', 'EX_acald_e', 'EX_pyr_e', 'PTAr', 'TALA'},
#  {'ACALD', 'ACONTa', 'PTAr', 'PYRt2', 'TALA'},
#  {'ACALDt', 'ACKr', 'ACONTb', 'EX_pyr_e', 'ICL', 'RPE'},
#  {'ACKr', 'ACONTb', 'EX_acald_e', 'EX_pyr_e', 'ICL', 'RPE'},
#  {'ACALD', 'CO2t', 'CS', 'NADTRHD', 'PTAr'},
#  {'ACALD', 'ACKr', 'ACONTb', 'EX_pyr_e', 'RPE'},
#  {'FRD7', 'MALS', 'NADTRHD', 'RPE', 'TALA'},
#  {'FRD7', 'GLUDy', 'GLUSy', 'MALS', 'NADTRHD'},
#  {'ACALD', 'ACONTa', 'CO2t', 'GND', 'PTAr'},
#  {'ACALD', 'ACONTa', 'ACt2r', 'CO2t', 'GND'},
#  {'ACALD', 'ACONTa', 'CO2t', 'EX_ac_e', 'GND'},
#  {'ACALD', 'CYTBD', 'EX_ac_e', 'LDH_D', 'PYRt2'},
#  {'ACALD', 'ACONTb', 'CO2t', 'G6PDH2r', 'PTAr'},
#  {'ACALD', 'ACKr', 'ACONTb', 'CO2t', 'G6PDH2r'},
#  {'ACALD', 'ACONTa', 'CO2t', 'G6PDH2r', 'PTAr'},
#  {'ACALD', 'ACONTa', 'ACt2r', 'CO2t', 'G6PDH2r'},
#  {'ACALD', 'ACONTb', 'ACt2r', 'CO2t', 'G6PDH2r'},
#  {'ACALD', 'CYTBD', 'EX_ac_e', 'EX_lac__D_e', 'PYRt2'},
#  {'ACALD', 'CYTBD', 'D_LACt2', 'EX_ac_e', 'PYRt2'},
#  {'ACKr', 'ACONTb', 'EX_acald_e', 'EX_pyr_e', 'TALA'},
#  {'ACALD', 'ACt2r', 'LDH_D', 'O2t', 'PYRt2'},
#  {'ACALD', 'CO2t', 'CS', 'PGL', 'PTAr'},
#  {'ACALD', 'ACKr', 'CO2t', 'CS', 'PGL'},
#  {'ACALD', 'ACt2r', 'CO2t', 'CS', 'PGL'},
#  {'ACALD', 'CO2t', 'CS', 'EX_ac_e', 'PGL'},
#  {'ACALD', 'EX_ac_e', 'EX_lac__D_e', 'EX_o2_e', 'PYRt2'},
#  {'ACALD', 'EX_ac_e', 'EX_lac__D_e', 'EX_o2_e', 'EX_pyr_e'},
#  {'ACALD', 'ACONTa', 'EX_pyr_e', 'PGL', 'PTAr'},
#  {'ACALD', 'ACKr', 'EX_lac__D_e', 'EX_pyr_e', 'O2t'},
#  {'ACALD', 'ADK1', 'EX_lac__D_e', 'EX_o2_e', 'PYRt2'},
#  {'ACALD', 'EX_lac__D_e', 'EX_o2_e', 'PPS', 'PYRt2'},
#  {'FRD7', 'MALS', 'NADTRHD', 'RPE', 'TKT2'},
#  {'ACALD', 'ACONTb', 'PTAr', 'PYRt2', 'RPE'},
#  {'ACALD', 'D_LACt2', 'EX_o2_e', 'PTAr', 'PYRt2'},
#  {'ACALD', 'EX_lac__D_e', 'EX_o2_e', 'PTAr', 'PYRt2'},
#  {'ACALD', 'ACt2r', 'CO2t', 'CS', 'NADTRHD'},
#  {'ACKr', 'CS', 'EX_acald_e', 'EX_pyr_e', 'RPI'},
#  {'ACALD', 'ADK1', 'EX_o2_e', 'LDH_D', 'PYRt2'},
#  {'ACALD', 'EX_o2_e', 'LDH_D', 'PPS', 'PYRt2'},
#  {'ACALD', 'CO2t', 'CS', 'GND', 'PTAr'},
#  {'ACALD', 'CO2t', 'CS', 'EX_ac_e', 'GND'},
#  {'ACALD', 'ACKr', 'CO2t', 'CS', 'GND'},
#  {'ACONTa', 'ACt2r', 'EX_acald_e', 'EX_pyr_e', 'TKT1'},
#  {'ACALD', 'ACKr', 'ACONTa', 'CO2t', 'G6PDH2r'},
#  {'ACALD', 'ACONTa', 'EX_pyr_e', 'PTAr', 'TALA'},
#  {'ACALD', 'ACONTb', 'ACt2r', 'EX_pyr_e', 'GND'},
#  {'ACKr', 'ACONTa', 'EX_acald_e', 'EX_pyr_e', 'RPE'},
#  {'ACALD', 'ACKr', 'CO2t', 'CS', 'NADTRHD'},
#  {'ACALD', 'ACONTb', 'CO2t', 'PTAr', 'TALA'},
#  {'ACALD', 'ACKr', 'ACONTb', 'CO2t', 'TALA'},
#  {'ACALD', 'ACONTb', 'CO2t', 'EX_ac_e', 'TALA'},
#  {'ACALD', 'ACONTb', 'ACt2r', 'CO2t', 'TALA'},
#  {'ACALD', 'ACONTa', 'CO2t', 'EX_ac_e', 'G6PDH2r', 'MALS'},
#  {'ACALDt', 'ACONTb', 'EX_pyr_e', 'ICL', 'PTAr', 'RPE'},
#  {'ACONTb', 'EX_acald_e', 'EX_pyr_e', 'ICL', 'PTAr', 'RPE'},
#  {'FRD7', 'ME1', 'NADTRHD', 'PYK', 'RPI'},
#  {'FRD7', 'ICL', 'NADTRHD', 'TKT1', 'TKT2'},
#  {'ACALD', 'CO2t', 'CS', 'G6PDH2r', 'PTAr'},
#  {'ACALD', 'ACt2r', 'CO2t', 'CS', 'G6PDH2r'},
#  {'ACALD', 'CO2t', 'CS', 'EX_ac_e', 'G6PDH2r'},
#  {'ACONTb', 'ACt2r', 'EX_acald_e', 'EX_pyr_e', 'RPI'},
#  {'ACALD', 'CYTBD', 'LDH_D', 'PTAr', 'PYRt2'},
#  {'ATPS4r', 'FRD7', 'NADTRHD', 'PIt2r', 'SUCCt2_2'},
#  {'ACALDt', 'ACKr', 'ACONTa', 'EX_pyr_e', 'G6PDH2r'},
#  {'ACKr', 'ACONTa', 'EX_acald_e', 'EX_pyr_e', 'G6PDH2r'},
#  {'ACALD', 'ACKr', 'ACONTa', 'EX_pyr_e', 'G6PDH2r'},
#  {'ACALD', 'ACONTb', 'EX_ac_e', 'EX_pyr_e', 'TALA'},
#  {'ACALD', 'EX_ac_e', 'EX_o2_e', 'EX_pyr_e', 'LDH_D'},
#  {'ATPS4r', 'BIOMASS_Ecoli_core_w_GAM', 'FRD7', 'NADTRHD', 'SUCCt2_2'},
#  {'ACALD', 'ACt2r', 'CO2t', 'CS', 'GND'},
#  {'ACALD', 'ACONTa', 'ACt2r', 'EX_pyr_e', 'RPI'},
#  {'ACALD', 'ACONTb', 'CO2t', 'PTAr', 'TKT1'},
#  {'ACALD', 'EX_lac__D_e', 'EX_o2_e', 'EX_pyr_e', 'PPS'},
#  {'ACALD', 'ACONTb', 'CO2t', 'EX_ac_e', 'TKT1'},
#  {'ACALD', 'ACONTb', 'ACt2r', 'CO2t', 'TKT1'},
#  {'FRD7', 'GLNS', 'ME1', 'NADTRHD', 'PYK'},
#  {'ATPS4r', 'FRD7', 'NADTRHD', 'NH4t', 'SUCCt2_2'},
#  {'ACALD', 'ACt2r', 'D_LACt2', 'EX_o2_e', 'PYRt2'},
#  {'ACALDt', 'ACONTb', 'PTAr', 'PYRt2', 'TKT2'},
#  {'ACALD', 'ACONTb', 'PTAr', 'PYRt2', 'TKT2'},
#  {'ACALD', 'EX_o2_e', 'LDH_D', 'PTAr', 'PYRt2'},
#  {'ACALD', 'ACKr', 'EX_o2_e', 'EX_pyr_e', 'LDH_D'},
#  {'ACALD', 'ACKr', 'EX_lac__D_e', 'EX_o2_e', 'EX_pyr_e'},
#  {'ACALDt', 'ACKr', 'ACONTb', 'EX_pyr_e', 'GND'},
#  {'ACKr', 'ACONTb', 'EX_acald_e', 'EX_pyr_e', 'GND'},
#  {'ACALD', 'ACKr', 'ACONTb', 'EX_pyr_e', 'GND'},
#  {'ACALD', 'D_LACt2', 'EX_ac_e', 'EX_o2_e', 'PYRt2'},
#  {'ACALD', 'ACKr', 'ACONTa', 'PYRt2', 'TKT1'},
#  {'FRD7', 'ICL', 'NADTRHD', 'RPE', 'TKT2'},
#  {'ACALD', 'ACKr', 'ACONTa', 'EX_pyr_e', 'RPE'},
#  {'ACALD', 'ACONTb', 'CO2t', 'PTAr', 'RPE'},
#  {'ACALD', 'ACONTa', 'CO2t', 'PTAr', 'RPE'},
#  {'ACALD', 'CO2t', 'CS', 'PTAr', 'RPE'},
#  {'ACALD', 'CO2t', 'CS', 'EX_ac_e', 'RPE'},
#  {'ACALD', 'ACKr', 'CO2t', 'CS', 'RPE'},
#  {'ACALD', 'ACONTa', 'CO2t', 'EX_ac_e', 'RPE'},
#  {'ACALD', 'ACKr', 'ACONTa', 'CO2t', 'RPE'},
#  {'ACALD', 'ACONTb', 'CO2t', 'PTAr', 'TKT2'},
#  {'ACALD', 'CYTBD', 'D_LACt2', 'EX_pyr_e', 'PPS'},
#  {'ACALD', 'ACKr', 'CO2t', 'CS', 'G6PDH2r'},
#  {'ACALDt', 'ACKr', 'ACONTb', 'PYRt2', 'TKT2'},
#  {'ACKr', 'ACONTb', 'EX_acald_e', 'PYRt2', 'TKT2'},
#  {'ACALDt', 'ACKr', 'CS', 'PYRt2', 'TKT1'},
#  {'ACALDt', 'ACKr', 'CS', 'EX_pyr_e', 'TKT1'},
#  {'ACALD', 'ACKr', 'CS', 'EX_pyr_e', 'TKT1'},
#  {'ACALD', 'ACKr', 'CS', 'PYRt2', 'TKT1'},
#  {'ACALD', 'CO2t', 'CS', 'EX_ac_e', 'NADTRHD'},
#  {'ACKr', 'ACONTa', 'EX_acald_e', 'EX_pyr_e', 'TALA'},
#  {'ACALD', 'ACt2r', 'EX_o2_e', 'EX_pyr_e', 'LDH_D'},
#  {'FRD7', 'ICDHyr', 'MDH', 'ME1', 'ME2'},
#  {'ACALD', 'ADK1', 'D_LACt2', 'EX_o2_e', 'EX_pyr_e'},
#  {'AKGDH', 'FRD7', 'MDH', 'ME1', 'ME2'},
#  {'ACALD', 'ACONTb', 'CO2t', 'PTAr', 'RPI'},
#  {'ACALD', 'ACONTb', 'ACt2r', 'CO2t', 'RPI'},
#  {'ACALD', 'ACONTa', 'CO2t', 'PTAr', 'RPI'},
#  {'ACALD', 'ACONTa', 'CO2t', 'EX_ac_e', 'RPI'},
#  {'FRD7', 'MDH', 'ME1', 'ME2', 'SUCOAS'},
#  {'ACALD', 'ACKr', 'ACONTb', 'CO2t', 'RPI'},
#  {'ACALD', 'ACKr', 'ACONTa', 'CO2t', 'RPI'},
#  {'ACALD', 'ACONTb', 'CO2t', 'EX_ac_e', 'RPI'},
#  {'ACALD', 'ACONTb', 'CO2t', 'EX_ac_e', 'TKT2'},
#  {'ACALD', 'ACONTb', 'EX_pyr_e', 'PTAr', 'RPE'},
#  {'ACALD', 'ADK1', 'EX_lac__D_e', 'EX_o2_e', 'EX_pyr_e'},
#  {'ACALD', 'ACONTb', 'ACt2r', 'CO2t', 'TKT2'},
#  {'ACALD', 'ACt2r', 'EX_lac__D_e', 'EX_o2_e', 'PYRt2'},
#  {'FRD7', 'MALS', 'NADTRHD', 'PGL', 'TKT1'},
#  {'FRD7', 'MALS', 'NADTRHD', 'PGL', 'RPE'},
#  {'FRD7', 'MALS', 'NADTRHD', 'PGL', 'TALA'},
#  {'FRD7', 'ICL', 'NADTRHD', 'PGL', 'TKT1'},
#  {'ACALD', 'EX_o2_e', 'EX_pyr_e', 'LDH_D', 'PTAr'},
#  {'ACALD', 'CYTBD', 'D_LACt2', 'EX_pyr_e', 'PTAr'},
#  {'ACALD', 'ACKr', 'ACONTb', 'PYRt2', 'TKT2'},
#  {'ACALD', 'ACKr', 'D_LACt2', 'EX_o2_e', 'EX_pyr_e'},
#  {'ACALD', 'ACONTb', 'CO2t', 'PGL', 'PTAr'},
#  {'ACALD', 'ACONTb', 'CO2t', 'EX_ac_e', 'PGL'},
#  {'ACALD', 'ACKr', 'ACONTb', 'CO2t', 'PGL'},
#  {'ACALD', 'ACONTb', 'ACt2r', 'CO2t', 'PGL'},
#  {'ACKr', 'CS', 'EX_acald_e', 'PYRt2', 'TKT1'},
#  {'ACALDt', 'ACKr', 'ACONTa', 'EX_pyr_e', 'MALS', 'RPI'},
#  {'ACONTb', 'EX_acald_e', 'EX_pyr_e', 'PTAr', 'TKT1'},
#  {'ACALD', 'ACKr', 'ACONTa', 'EX_pyr_e', 'RPI'},
#  {'ACALD', 'ACKr', 'ACONTb', 'CO2t', 'TKT1'},
#  {'ACALDt', 'ACKr', 'ACONTa', 'PYRt2', 'RPI'},
#  {'ACKr', 'ACONTa', 'EX_acald_e', 'MALS', 'PYRt2', 'RPI'},
#  {'ACALD', 'ACONTb', 'CO2t', 'NADTRHD', 'PTAr'},
#  {'ACALD', 'ACONTb', 'CO2t', 'EX_ac_e', 'NADTRHD'},
#  {'ACALD', 'ACONTb', 'ACt2r', 'CO2t', 'NADTRHD'},
#  {'ACALDt', 'ACKr', 'ACONTb', 'EX_pyr_e', 'RPI'},
#  {'ATPS4r', 'FRD7', 'GLNS', 'NADTRHD', 'SUCCt2_2'},
#  {'ACALDt', 'ACKr', 'ACONTa', 'EX_pyr_e', 'TKT1'},
#  {'ACALD', 'ACKr', 'ACONTa', 'EX_pyr_e', 'TKT1'},
#  {'ACKr', 'ACONTa', 'EX_acald_e', 'EX_pyr_e', 'TKT1'},
#  {'ACALDt', 'CS', 'EX_ac_e', 'PYRt2', 'RPE'},
#  {'ACALD', 'CS', 'EX_ac_e', 'PYRt2', 'RPE'},
#  {'ACKr', 'ACONTb', 'EX_acald_e', 'EX_pyr_e', 'RPI'},
#  {'ACALD', 'CO2t', 'CS', 'PTAr', 'RPI'},
#  {'ACALD', 'ACKr', 'CO2t', 'CS', 'RPI'},
#  {'ACALD', 'CO2t', 'CS', 'EX_ac_e', 'RPI'},
#  {'ACALD', 'ACt2r', 'CO2t', 'CS', 'RPI'},
#  {'ACALD', 'ACKr', 'ACONTa', 'CO2t', 'GND'},
#  {'ACALD', 'ACKr', 'ACONTb', 'CO2t', 'TKT2'},
#  {'ACALD', 'ACONTb', 'CO2t', 'GND', 'PTAr'},
#  {'ACALD', 'ACKr', 'ACONTb', 'CO2t', 'GND'},
#  {'ACALD', 'ACONTb', 'ACt2r', 'CO2t', 'GND'},
#  {'ACALD', 'ACONTb', 'CO2t', 'EX_ac_e', 'GND'},
#  {'ACALD', 'ACONTb', 'GND', 'PTAr', 'PYRt2'},
#  {'ACALD', 'CYTBD', 'EX_ac_e', 'EX_lac__D_e', 'EX_pyr_e'},
#  {'ACALD', 'ACt2r', 'CO2t', 'CS', 'RPE'},
#  {'ACALD', 'ACONTb', 'CO2t', 'EX_ac_e', 'RPE'},
#  {'ACALDt', 'ACONTa', 'EX_ac_e', 'EX_pyr_e', 'PGL'},
#  {'ACONTa', 'EX_ac_e', 'EX_acald_e', 'EX_pyr_e', 'PGL'},
#  {'ACALD', 'ACONTa', 'EX_ac_e', 'EX_pyr_e', 'PGL'},
#  {'ACALDt', 'ACONTa', 'EX_ac_e', 'PGL', 'PYRt2'},
#  {'ACONTa', 'EX_ac_e', 'EX_acald_e', 'PGL', 'PYRt2'},
#  {'ACALD', 'ACONTa', 'EX_ac_e', 'PGL', 'PYRt2'},
#  {'ACALD', 'CYTBD', 'D_LACt2', 'EX_ac_e', 'EX_pyr_e'},
#  {'ACKr', 'CS', 'EX_acald_e', 'EX_pyr_e', 'TKT1'},
#  {'ACALD', 'ACONTa', 'ACt2r', 'CO2t', 'RPE'},
#  {'ACALD', 'EX_ac_e', 'EX_o2_e', 'LDH_D', 'PYRt2'},
#  {'FRD7', 'ICL', 'NADTRHD', 'PGL', 'TALA'},
#  {'ACALD', 'D_LACt2', 'EX_o2_e', 'PPS', 'PYRt2'},
#  {'ACALD', 'ACt2r', 'D_LACt2', 'EX_o2_e', 'EX_pyr_e'},
#  {'FRD7', 'MALS', 'NADTRHD', 'PGL', 'TKT2'},
#  {'ATPS4r', 'FRD7', 'RPE', 'SUCCt2_2', 'THD2'},
#  {'ACALD', 'ACONTa', 'CO2t', 'PTAr', 'TALA'},
#  {'ACALD', 'ACKr', 'ACONTb', 'CO2t', 'NADTRHD'},
#  {'ACALD', 'D_LACt2', 'EX_o2_e', 'EX_pyr_e', 'PPS'},
#  {'ACALD', 'ACONTa', 'CO2t', 'EX_ac_e', 'TALA'},
#  {'ACALD', 'ACONTa', 'ACt2r', 'CO2t', 'TALA'},
#  {'ACALD', 'CYTBD', 'EX_ac_e', 'EX_pyr_e', 'LDH_D'},
#  {'ACALD', 'ACONTb', 'ACt2r', 'CO2t', 'RPE'},
#  {'ATPS4r', 'FRD7', 'RPI', 'SUCCt2_2', 'THD2'},
#  {'FRD7', 'GND', 'ICL', 'NADTRHD', 'RPE'},
#  {'ACALDt', 'ACONTa', 'EX_ac_e', 'EX_pyr_e', 'RPI'},
#  {'ACALDt', 'ACONTa', 'EX_ac_e', 'ICL', 'PYRt2', 'RPI'},
#  {'ACONTa', 'EX_ac_e', 'EX_acald_e', 'PYRt2', 'RPI'},
#  {'ACONTa', 'EX_ac_e', 'EX_acald_e', 'EX_pyr_e', 'RPI'},
#  {'ATPS4r', 'FRD7', 'ICDHyr', 'SUCCt2_2', 'THD2'},
#  {'ACKr', 'ACONTa', 'EX_acald_e', 'EX_pyr_e', 'RPI'},
#  {'ACALD', 'CYTBD', 'EX_lac__D_e', 'PPS', 'PYRt2'},
#  {'ACALD', 'ACONTb', 'CO2t', 'EX_ac_e', 'G6PDH2r'},
#  {'ATPS4r', 'FRD7', 'NH4t', 'SUCCt2_2', 'THD2'},
#  {'ACALD', 'ACt2r', 'D_LACt2', 'EX_pyr_e', 'O2t'},
#  {'ACALD', 'ACONTa', 'CO2t', 'NADTRHD', 'PTAr'},
#  {'ACALD', 'ACONTa', 'ACt2r', 'CO2t', 'NADTRHD'},
#  {'FRD7', 'ICL', 'NADTRHD', 'PGL', 'RPE'},
#  {'ACALD', 'ACONTa', 'CO2t', 'EX_ac_e', 'NADTRHD'},
#  {'ACALDt', 'ACONTb', 'EX_ac_e', 'EX_pyr_e', 'RPE'},
#  {'ACONTb', 'EX_ac_e', 'EX_acald_e', 'EX_pyr_e', 'RPE'},
#  {'ACALD', 'ADK1', 'CYTBD', 'EX_pyr_e', 'LDH_D'},
#  {'ACALD', 'ACt2r', 'EX_o2_e', 'LDH_D', 'PYRt2'},
#  {'ACALD', 'CYTBD', 'EX_pyr_e', 'LDH_D', 'PPS'},
#  {'ATPS4r', 'FRD7', 'GLNS', 'SUCCt2_2', 'THD2'},
#  {'ACALD', 'ACONTb', 'EX_ac_e', 'EX_pyr_e', 'RPE'},
#  {'FRD7', 'GND', 'ICL', 'NADTRHD', 'TKT2'},
#  {'ACALD', 'CYTBD', 'EX_lac__D_e', 'PTAr', 'PYRt2'},
#  {'FRD7', 'G6PDH2r', 'ICL', 'NADTRHD', 'TALA'},
#  {'ACALD', 'ACONTb', 'PTAr', 'PYRt2', 'TKT1'},
#  {'FRD7', 'G6PDH2r', 'ICL', 'NADTRHD', 'TKT1'},
#  {'FRD7', 'G6PDH2r', 'ICL', 'NADTRHD', 'RPE'},
#  {'FRD7', 'G6PDH2r', 'MALS', 'NADTRHD', 'TKT1'},
#  {'FRD7', 'G6PDH2r', 'MALS', 'NADTRHD', 'TKT2'},
#  {'FRD7', 'G6PDH2r', 'ICL', 'NADTRHD', 'TKT2'},
#  {'FRD7', 'G6PDH2r', 'MALS', 'NADTRHD', 'RPE'},
#  {'ACALD', 'ACt2r', 'CYTBD', 'EX_pyr_e', 'LDH_D'},
#  {'FRD7', 'ICL', 'NADTRHD', 'PGL', 'TKT2'},
#  {'ACALDt', 'ACt2r', 'CS', 'PYRt2', 'TALA'},
#  {'ACt2r', 'CS', 'EX_acald_e', 'PYRt2', 'TALA'},
#  {'ACALDt', 'ACt2r', 'CS', 'MALS', 'PYRt2', 'RPE'},
#  {'ACt2r', 'CS', 'EX_acald_e', 'MALS', 'PYRt2', 'RPE'},
#  {'ACALDt', 'ACt2r', 'CS', 'PYRt2', 'RPI'},
#  {'ACt2r', 'CS', 'EX_acald_e', 'PYRt2', 'RPI'},
#  {'ACALDt', 'ACt2r', 'CS', 'G6PDH2r', 'MALS', 'PYRt2'},
#  {'ACALD', 'ACKr', 'EX_o2_e', 'LDH_D', 'PYRt2'},
#  {'ACALD', 'ACKr', 'D_LACt2', 'EX_o2_e', 'PYRt2'},
#  {'ACALD', 'ACKr', 'EX_lac__D_e', 'EX_o2_e', 'PYRt2'},
#  {'ACALD', 'CS', 'EX_ac_e', 'EX_pyr_e', 'TALA'},
#  {'ACALDt', 'CS', 'EX_ac_e', 'EX_pyr_e', 'G6PDH2r'},
#  {'CS', 'EX_ac_e', 'EX_acald_e', 'EX_pyr_e', 'G6PDH2r'},
#  {'ACALDt', 'CS', 'EX_ac_e', 'G6PDH2r', 'PYRt2'},
#  {'CS', 'EX_ac_e', 'EX_acald_e', 'G6PDH2r', 'PYRt2'},
#  {'ACALD', 'CS', 'EX_ac_e', 'G6PDH2r', 'PYRt2'},
#  {'ACALDt', 'ACKr', 'CS', 'PYRt2', 'TALA'},
#  {'ACALD', 'ACKr', 'CS', 'PYRt2', 'TALA'},
#  {'ACKr', 'CS', 'EX_acald_e', 'PYRt2', 'TALA'},
#  {'ACALDt', 'ACKr', 'CS', 'EX_pyr_e', 'TALA'},
#  {'ACALD', 'ACKr', 'CYTBD', 'EX_pyr_e', 'LDH_D'},
#  {'ACALD', 'ACKr', 'CYTBD', 'EX_lac__D_e', 'EX_pyr_e'},
#  {'ACALD', 'ACKr', 'ACONTa', 'CO2t', 'TALA'},
#  {'ACALDt', 'ACONTb', 'EX_pyr_e', 'PTAr', 'TKT2'},
#  {'ACALD', 'ACONTb', 'EX_pyr_e', 'PTAr', 'TKT2'},
#  {'ACALDt', 'ACONTb', 'EX_ac_e', 'EX_pyr_e', 'TKT2'},
#  {'ACALD', 'ACONTb', 'EX_ac_e', 'EX_pyr_e', 'TKT2'},
#  {'ACONTb', 'EX_acald_e', 'EX_pyr_e', 'PTAr', 'TKT2'},
#  {'ACONTb', 'EX_ac_e', 'EX_acald_e', 'EX_pyr_e', 'TKT2'},
#  {'ACALDt', 'ACONTb', 'ACt2r', 'EX_pyr_e', 'TKT2'},
#  {'ACALD', 'ACONTb', 'ACt2r', 'EX_pyr_e', 'TKT2'},
#  {'ACONTb', 'ACt2r', 'EX_acald_e', 'EX_pyr_e', 'TKT2'},
#  {'ACALDt', 'ACKr', 'ACONTa', 'PYRt2', 'TKT2'},
#  {'ACKr', 'ACONTa', 'EX_acald_e', 'PYRt2', 'TKT2'},
#  {'ACALD', 'ACKr', 'ACONTa', 'PYRt2', 'TKT2'},
#  {'ACALDt', 'ACKr', 'ACONTa', 'PYRt2', 'TALA'},
#  {'ACKr', 'ACONTa', 'EX_acald_e', 'PYRt2', 'TALA'},
#  {'ACALD', 'ACKr', 'ACONTa', 'PYRt2', 'TALA'},
#  {'ACALD', 'CYTBD', 'D_LACt2', 'PTAr', 'PYRt2'},
#  ...]

# %% [markdown]
# ## Constraint-based analysis of mutant phenotypes

# %% [markdown]
# In this format, we can easily use COBRA to analyse these knockouts. In this snippet, a dictionary is created to store various simulation values obtained after applying the reaction knockouts suggested by the MCSs. These are:
# * *product_minimum* and *product_maximum* - Flux range for succinate production
# * *max_growth* - Maximum growth rate
# * *product_at_max_growth* - Predicted production rate at maximum growth
# * *glucose_consumption* - Glucose consumption rate at maximum growth

# %%
def analyse(kos):
    apply_kos(kos)
    try:
        sol = model.optimize()

        biomass = sol.fluxes.BIOMASS_Ecoli_core_w_GAM
        product = sol.fluxes.EX_succ_e
        substrate = sol.fluxes.EX_glc__D_e
        fva = cobra.flux_analysis.variability.flux_variability_analysis(model, reaction_list=['EX_succ_e']).loc['EX_succ_e',:]
        
        return {
        'product_maximum': fva['maximum'],
        'product_minimum': fva['minimum'],
        'max_growth': biomass,
        'product_at_max_growth':product,
        'glucose_consumption': substrate
        }
    
    except:
        pass
    finally:
        revert_bounds()
    return

# %% [markdown]
# *pandas* can be used to store these values as a dataframe for easier manipulation and analysis

# %%
import pandas as pd

df = pd.DataFrame({frozenset(ko): analyse(ko) for ko in mcs}).T
# Out:
# cobra/util/solver.py:408 UserWarning: solver status is 'infeasible'

# %% [markdown]
# Solutions with null or very low growth, as well as solutions with very low production rates are filtered out. This way, only the best candidates are displayed

# %%
null_growth = df.max_growth.isnull()
zero_growth = df.max_growth <= 1e-10
no_product = df.product_at_max_growth <= 1e-5

df[~ (zero_growth | null_growth | no_product)].sort_values(by='max_growth', ascending=False)
# Out:
#                                               glucose_consumption max_growth  \
# (ACALD, O2t, PPS, PYRt2, LDH_D)                               -10   0.110886
# (ADK1, ACALD, CYTBD, PYRt2, LDH_D)                            -10   0.110886
# (O2t, D_LACt2, ACALD, PYRt2, ADK1)                            -10   0.110886
# (D_LACt2, ACALD, EX_pyr_e, CYTBD, ADK1)                       -10   0.110886
# (ACALD, D_LACt2, CYTBD, PYRt2, ADK1)                          -10   0.110886
# (ACALD, EX_lac__D_e, CYTBD, PYRt2, ADK1)                      -10   0.110886
# (ADK1, O2t, ACALD, PYRt2, EX_lac__D_e)                        -10   0.110886
# (ADK1, O2t, ACALD, PYRt2, LDH_D)                              -10   0.110886
# (EX_o2_e, EX_pyr_e, ACALD, D_LACt2, PPS)                      -10   0.110886
# (PPS, O2t, ACALD, PYRt2, EX_lac__D_e)                         -10   0.110886
# (ADK1, EX_o2_e, ACALD, PYRt2, LDH_D)                          -10   0.110886
# (EX_o2_e, D_LACt2, ACALD, PYRt2, ADK1)                        -10   0.110886
# (CYTBD, ACALD, EX_pyr_e, PPS, LDH_D)                          -10   0.110886
# (ADK1, ACALD, EX_pyr_e, CYTBD, LDH_D)                         -10   0.110886
# (EX_o2_e, EX_lac__D_e, ACALD, PYRt2, ADK1)                    -10   0.110886
# (ACALD, O2t, EX_pyr_e, PPS, LDH_D)                            -10   0.110886
# (ACALD, CYTBD, EX_lac__D_e, PPS, PYRt2)                       -10   0.110886
# (PPS, D_LACt2, O2t, EX_pyr_e, ACALD)                          -10   0.110886
# (PPS, O2t, EX_pyr_e, ACALD, EX_lac__D_e)                      -10   0.110886
# (EX_o2_e, ACALD, EX_pyr_e, PPS, LDH_D)                        -10   0.110886
# (D_LACt2, O2t, EX_pyr_e, ACALD, ADK1)                         -10   0.110886
# (PPS, O2t, D_LACt2, ACALD, PYRt2)                             -10   0.110886
# (PPS, EX_o2_e, EX_lac__D_e, ACALD, PYRt2)                     -10   0.110886
# (EX_o2_e, ACALD, PPS, PYRt2, LDH_D)                           -10   0.110886
# (EX_o2_e, EX_lac__D_e, EX_pyr_e, ACALD, ADK1)                 -10   0.110886
# (ADK1, O2t, EX_pyr_e, ACALD, EX_lac__D_e)                     -10   0.110886
# (PPS, EX_o2_e, EX_lac__D_e, EX_pyr_e, ACALD)                  -10   0.110886
# (CYTBD, D_LACt2, ACALD, EX_pyr_e, PPS)                        -10   0.110886
# (ACALD, EX_lac__D_e, EX_pyr_e, CYTBD, ADK1)                   -10   0.110886
# (ADK1, EX_o2_e, EX_pyr_e, ACALD, LDH_D)                       -10   0.110886
# (EX_o2_e, EX_pyr_e, D_LACt2, ACALD, ADK1)                     -10   0.110886
# (ACALD, CYTBD, EX_lac__D_e, EX_pyr_e, PPS)                    -10   0.110886
# (CYTBD, ACALD, D_LACt2, PPS, PYRt2)                           -10   0.110886
# (CYTBD, ACALD, PPS, PYRt2, LDH_D)                             -10   0.110886
# (EX_o2_e, PPS, D_LACt2, ACALD, PYRt2)                         -10   0.110886
# (ADK1, O2t, EX_pyr_e, ACALD, LDH_D)                           -10   0.110886
# (ATPS4r, EX_co2_e, PGI)                                       -10  0.0187589
# (ATPS4r, CO2t, PGI)                                           -10  0.0187589
#
#                                               product_at_max_growth  \
# (ACALD, O2t, PPS, PYRt2, LDH_D)                             9.09864
# (ADK1, ACALD, CYTBD, PYRt2, LDH_D)                          9.09864
# (O2t, D_LACt2, ACALD, PYRt2, ADK1)                          9.09864
# (D_LACt2, ACALD, EX_pyr_e, CYTBD, ADK1)                     9.09864
# (ACALD, D_LACt2, CYTBD, PYRt2, ADK1)                        9.09864
# (ACALD, EX_lac__D_e, CYTBD, PYRt2, ADK1)                    9.09864
# (ADK1, O2t, ACALD, PYRt2, EX_lac__D_e)                      9.09864
# (ADK1, O2t, ACALD, PYRt2, LDH_D)                            9.09864
# (EX_o2_e, EX_pyr_e, ACALD, D_LACt2, PPS)                    9.09864
# (PPS, O2t, ACALD, PYRt2, EX_lac__D_e)                       9.09864
# (ADK1, EX_o2_e, ACALD, PYRt2, LDH_D)                        9.09864
# (EX_o2_e, D_LACt2, ACALD, PYRt2, ADK1)                      9.09864
# (CYTBD, ACALD, EX_pyr_e, PPS, LDH_D)                        9.09864
# (ADK1, ACALD, EX_pyr_e, CYTBD, LDH_D)                       9.09864
# (EX_o2_e, EX_lac__D_e, ACALD, PYRt2, ADK1)                  9.09864
# (ACALD, O2t, EX_pyr_e, PPS, LDH_D)                          9.09864
# (ACALD, CYTBD, EX_lac__D_e, PPS, PYRt2)                     9.09864
# (PPS, D_LACt2, O2t, EX_pyr_e, ACALD)                        9.09864
# (PPS, O2t, EX_pyr_e, ACALD, EX_lac__D_e)                    9.09864
# (EX_o2_e, ACALD, EX_pyr_e, PPS, LDH_D)                      9.09864
# (D_LACt2, O2t, EX_pyr_e, ACALD, ADK1)                       9.09864
# (PPS, O2t, D_LACt2, ACALD, PYRt2)                           9.09864
# (PPS, EX_o2_e, EX_lac__D_e, ACALD, PYRt2)                   9.09864
# (EX_o2_e, ACALD, PPS, PYRt2, LDH_D)                         9.09864
# (EX_o2_e, EX_lac__D_e, EX_pyr_e, ACALD, ADK1)               9.09864
# (ADK1, O2t, EX_pyr_e, ACALD, EX_lac__D_e)                   9.09864
# (PPS, EX_o2_e, EX_lac__D_e, EX_pyr_e, ACALD)                9.09864
# (CYTBD, D_LACt2, ACALD, EX_pyr_e, PPS)                      9.09864
# (ACALD, EX_lac__D_e, EX_pyr_e, CYTBD, ADK1)                 9.09864
# (ADK1, EX_o2_e, EX_pyr_e, ACALD, LDH_D)                     9.09864
# (EX_o2_e, EX_pyr_e, D_LACt2, ACALD, ADK1)                   9.09864
# (ACALD, CYTBD, EX_lac__D_e, EX_pyr_e, PPS)                  9.09864
# (CYTBD, ACALD, D_LACt2, PPS, PYRt2)                         9.09864
# (CYTBD, ACALD, PPS, PYRt2, LDH_D)                           9.09864
# (EX_o2_e, PPS, D_LACt2, ACALD, PYRt2)                       9.09864
# (ADK1, O2t, EX_pyr_e, ACALD, LDH_D)                         9.09864
# (ATPS4r, EX_co2_e, PGI)                                     9.96264
# (ATPS4r, CO2t, PGI)                                         9.96264
#
#                                               product_maximum product_minimum
# (ACALD, O2t, PPS, PYRt2, LDH_D)                       9.09864         9.09864
# (ADK1, ACALD, CYTBD, PYRt2, LDH_D)                    9.09864         9.09864
# (O2t, D_LACt2, ACALD, PYRt2, ADK1)                    9.09864         9.09864
# (D_LACt2, ACALD, EX_pyr_e, CYTBD, ADK1)               9.09864         9.09864
# (ACALD, D_LACt2, CYTBD, PYRt2, ADK1)                  9.09864         9.09864
# (ACALD, EX_lac__D_e, CYTBD, PYRt2, ADK1)              9.09864         9.09864
# (ADK1, O2t, ACALD, PYRt2, EX_lac__D_e)                9.09864         9.09864
# (ADK1, O2t, ACALD, PYRt2, LDH_D)                      9.09864         9.09864
# (EX_o2_e, EX_pyr_e, ACALD, D_LACt2, PPS)              9.09864         9.09864
# (PPS, O2t, ACALD, PYRt2, EX_lac__D_e)                 9.09864         9.09864
# (ADK1, EX_o2_e, ACALD, PYRt2, LDH_D)                  9.09864         9.09864
# (EX_o2_e, D_LACt2, ACALD, PYRt2, ADK1)                9.09864         9.09864
# (CYTBD, ACALD, EX_pyr_e, PPS, LDH_D)                  9.09864         9.09864
# (ADK1, ACALD, EX_pyr_e, CYTBD, LDH_D)                 9.09864         9.09864
# (EX_o2_e, EX_lac__D_e, ACALD, PYRt2, ADK1)            9.09864         9.09864
# (ACALD, O2t, EX_pyr_e, PPS, LDH_D)                    9.09864         9.09864
# (ACALD, CYTBD, EX_lac__D_e, PPS, PYRt2)               9.09864         9.09864
# (PPS, D_LACt2, O2t, EX_pyr_e, ACALD)                  9.09864         9.09864
# (PPS, O2t, EX_pyr_e, ACALD, EX_lac__D_e)              9.09864         9.09864
# (EX_o2_e, ACALD, EX_pyr_e, PPS, LDH_D)                9.09864         9.09864
# (D_LACt2, O2t, EX_pyr_e, ACALD, ADK1)                 9.09864         9.09864
# (PPS, O2t, D_LACt2, ACALD, PYRt2)                     9.09864         9.09864
# (PPS, EX_o2_e, EX_lac__D_e, ACALD, PYRt2)             9.09864         9.09864
# (EX_o2_e, ACALD, PPS, PYRt2, LDH_D)                   9.09864         9.09864
# (EX_o2_e, EX_lac__D_e, EX_pyr_e, ACALD, ADK1)         9.09864         9.09864
# (ADK1, O2t, EX_pyr_e, ACALD, EX_lac__D_e)             9.09864         9.09864
# (PPS, EX_o2_e, EX_lac__D_e, EX_pyr_e, ACALD)          9.09864         9.09864
# (CYTBD, D_LACt2, ACALD, EX_pyr_e, PPS)                9.09864         9.09864
# (ACALD, EX_lac__D_e, EX_pyr_e, CYTBD, ADK1)           9.09864         9.09864
# (ADK1, EX_o2_e, EX_pyr_e, ACALD, LDH_D)               9.09864         9.09864
# (EX_o2_e, EX_pyr_e, D_LACt2, ACALD, ADK1)             9.09864         9.09864
# (ACALD, CYTBD, EX_lac__D_e, EX_pyr_e, PPS)            9.09864         9.09864
# (CYTBD, ACALD, D_LACt2, PPS, PYRt2)                   9.09864         9.09864
# (CYTBD, ACALD, PPS, PYRt2, LDH_D)                     9.09864         9.09864
# (EX_o2_e, PPS, D_LACt2, ACALD, PYRt2)                 9.09864         9.09864
# (ADK1, O2t, EX_pyr_e, ACALD, LDH_D)                   9.09864         9.09864
# (ATPS4r, EX_co2_e, PGI)                               9.96264         9.96264
# (ATPS4r, CO2t, PGI)                                   9.96264         9.96264
